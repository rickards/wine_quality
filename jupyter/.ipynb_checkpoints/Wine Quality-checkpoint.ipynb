# %% [markdown]
# # Modelagem dos dados

# %%
import math
import keras
import numpy as np
import pandas as pd
import seaborn as sns

from scipy import stats
from sklearn import preprocessing
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Leitura dos dados

# %%
df = pd.read_csv("./../winequality.csv", sep=";")
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  White            7.0              0.27         0.36            20.7
# 1  White            6.3              0.30         0.34             1.6
# 2  White            8.1              0.28         0.40             6.9
# 3  White            7.2              0.23         0.32             8.5
# 4  White            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates alcohol  quality
# 0       0.45     8.8        6
# 1       0.49     9.5        6
# 2       0.44    10.1        6
# 3       0.40     9.9        6
# 4       0.40     9.9        6

# %% [markdown]
# ### Vejamos os tipos de dados de cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   object
#  12  quality               6497 non-null   int64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 660.0+ KB

# %% [markdown]
# ### TRATAMENTO DO BANCO DE DADOS
#
# Se observado os dados type e alcohol são objects, precisamos só trabalhar com números.
#
# * type: object (vamos mudar para inteiro)
# * alcohol: object (vamos mudar para float e eliminar dados incosistentes)

# %%
#adicionar números como representantes das categorias
df['type'] = df['type'].map( {'White': 1, 'Red': 0} ).astype(int)
#vamos corrigir os erros da coluna, e substituí-los para NaN, em seguida preencher essas lacunas com a moda
#poderiamos ignorá-los, mas cada dado é valioso e vamos investigar usando essas dados corrompidos
df['alcohol'] = pd.to_numeric(df['alcohol'], errors='coerce')
freq_port = df.alcohol.dropna().mode()[0]
df['alcohol'] = df['alcohol'].fillna(freq_port)

# %% [markdown]
# ### Agora os dados são apenas números!!!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   int64
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.0             0.270         0.36            20.7
# 1        1            6.3             0.300         0.34             1.6
# 2        1            8.1             0.280         0.40             6.9
# 3        1            7.2             0.230         0.32             8.5
# 4        1            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492     0            6.2             0.600         0.08             2.0
# 6493     0            5.9             0.550         0.10             2.2
# 6494     0            6.3             0.510         0.13             2.3
# 6495     0            5.9             0.645         0.12             2.0
# 6496     0            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493       0.76     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %% [markdown]
# ### Para começar a análise, vamos ver como a distribuição dos dados se dá

# %%
df.boxplot(column=list(df.columns[:-1]))

# %% [markdown]
# ### Percebe-se que alguns atributos tem valores discrepantes, para melhorar essa visualização e não enviesar nossos modelos (alguns podem ser enviesados por essa discrepâcia de valores), vamos normalizar esses dados.

# %%
x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled, columns=df.columns)
df_normalized['quality'] = df['quality']
df = df_normalized

df.boxplot(column=list(df.columns[:-1]))

# %% [markdown]
# ### Como podem ver, alguns atributos tem outliers, vamos remove-los.

# %%
#REMOVER OUTLIERS
z_scores = stats.zscore(df) #calculate z-scores of `df` média 0 desvio padrão 1
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df_without_outliers = df[filtered_entries]

df_without_outliers.boxplot(column=list(df.columns[:-1]))

# %%
df_without_outliers[['quality', 'type']].groupby(['quality'], as_index=False).mean().sort_values(by='quality', ascending=False)
# Out:
#    quality      type
# 4        8  0.929348
# 3        7  0.847953
# 2        6  0.802587
# 1        5  0.714066
# 0        4  0.836957

# %% [markdown]
# ### Ao remover os outliers, percebemos que os dados de qualidade 3 e 9 são removidos, então eles são relevantes e devem permanecer junto com os dados.
#
# ### Agora vamos ver como o atributo quality está distribuido na coluna type novamente, mas com outra perspectiva.

# %%
df[['quality', 'type']].groupby(['quality'], as_index=False).mean().sort_values(by='quality', ascending=False)
# Out:
#    quality      type
# 6        9  1.000000
# 5        8  0.906736
# 4        7  0.815570
# 3        6  0.775035
# 2        5  0.681478
# 1        4  0.754630
# 0        3  0.666667

# %% [markdown]
# ### Atributo type parece mostrar que a incidência de vinhos de qualidade maior estão mais presentes no vinho branco. Isso se deve também a quantidade de vinhos Brancos que são sua maioria.
#
# ### Vamos interpretar atributo por atributo.

# %%
ax = sns.violinplot(x="quality", y="fixed acidity", data=df)

# %% [markdown]
# ### Esse atributo não parece ser muito descritivo porém, para os casos de qualidade 3 e 9, eles se dirvegem com uma barriga maior (maior frequência dos dados) nos vinhos de alta qualidade.
#
# ### Vamos ao próximo atributo.

# %%
ax = sns.boxplot(x="quality", y="volatile acidity", data=df)

# %% [markdown]
# ### Esse atributo já mostrou uma variedada correlacionada a qualidade, apesar de pouca.
#
# ### Interessante atributo, correlação decrescente
#
# ### Vamos ao próximo:

# %%
ax = sns.boxplot(x="quality", y="citric acid", data=df)

# %% [markdown]
# ### Isoladamente não parece um bom atributo, mas podemos ver quando ele se combina com outro, sempre que isso ocorre, separamos esses casos para aumentar ou diminuir a dimensionalidade e verificar correlações, por enquanto mantemos.
#
# ### Segue o residual sugar

# %%
ax = sns.boxplot(x="quality", y="residual sugar", data=df)

# %% [markdown]
# ### Mesma situação do anterior citric acid

# %%
ax = sns.boxplot(x="quality", y="chlorides", data=df)

# %% [markdown]
# ### Sutilmente os vinhos com mais qualidade estão em um intervalo mais curto

# %%
ax = sns.boxplot(x="quality", y="free sulfur dioxide", data=df)

# %% [markdown]
# ### Sutil correlação decrescente e estreitamento do intervalo em vinhos com mais qualidade.

# %%
ax = sns.boxplot(x="quality", y="total sulfur dioxide", data=df)

# %% [markdown]
# ### Algumas características só aparecem em vinhos com qualidade inferior, o intervalo fica mais concentrados a medida que a qualidade aumenta.

# %%
ax = sns.violinplot(x="quality", y="density", data=df)

# %% [markdown]
# ### Variação inconsistente, os valores aparecem sem seguir crescente estável, nesses casos vamos categorizar por alguns intervalos.

# %%
# vamos categorizar, agrupar alguns intervalos
df.loc[ df['density'] <= 0.2, 'density'] = 0
df.loc[(df['density'] > 0.2) & (df['density'] <= 0.6), 'density'] = 0.5
df.loc[ df['density'] > 0.6, 'density'] = 1
df['density'] = df['density'].astype(int)
df[['quality', 'density']].groupby(['quality'], as_index=False).mean().sort_values(by='quality', ascending=False)
# Out:
#    quality   density
# 6        9  0.000000
# 5        8  0.000000
# 4        7  0.002780
# 3        6  0.005289
# 2        5  0.008887
# 1        4  0.004630
# 0        3  0.000000

# %% [markdown]
# ### Vinhos com densidade maior são representados com pior qualidade, com algumas exceções, inclusivo para os vinhos de pior qualidade, o que dificulta na discriminação da amostra.
#
# ### Vamos a próxima característica:

# %%
ax = sns.violinplot(x="quality", y="pH", data=df)

# %% [markdown]
# ### Quanto maior a qualidade, mais restrito são os valores aceitáveis de ph do vinho
#
# ### Vamos a próxima característica:

# %%
ax = sns.boxplot(x="quality", y="sulphates", data=df)

# %% [markdown]
# ### Não parece ser um bom atributo, porém delimita subconjuntos simples (3 e 9), (7 e 8) e (4, 5 e 6)

# %%
ax = sns.boxplot(x="quality", y="alcohol", data=df)

# %% [markdown]
# ### Ótimo atributo, mostra-se bom representante para bons vinhos
#
# ### Agora vamos separar os atributos ruins e intercala-los com outros atributos para ver se encontra algum padrão para representar bons vinhos:
#
# ### Vamos começar com

# %%
ax2 = df.plot.scatter(x='citric acid',
                      y='chlorides',
                      c='quality',
                      colormap='viridis')

# %% [markdown]
# ### Isoladamente não parece um bom preditor, mas quando combinado com chlorides, parece ter algum potencial, ver-se que os melhores qualificados vinhos estão na parte inferior do gráfico, apesar de sutil.

# %%
ax2 = df.plot.scatter(x='residual sugar',
                      y='chlorides',
                      c='quality',
                      colormap='viridis')

# %% [markdown]
# ### Isoladamente não parece um bom preditor, mas quando combinado com chlorides, um sutil correlação acontece. Quanto mais distante da região inferior esquerda, menor a qualidade do vinho.

# %% [markdown]
# ### Por fim vamos adicionar um atributo relacionado a proporção de dioxide, adicionado como joy example para mostrar que algumas derivações de atributos foram avaliadas.

# %%
# Adiciono uma nova variável com a proporção de dioxide
df['prop dioxide'] = df['free sulfur dioxide']/df['total sulfur dioxide']

ax2 = df.plot.scatter(x='free sulfur dioxide',
                      y='total sulfur dioxide',
                      c='quality',
                      colormap='viridis')

# %%
ax3 = sns.boxplot(x="quality", y="prop dioxide", data=df)

# %% [markdown]
# # Machine Learning

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Vamos selecionar nossas técnicas

# %%
machine_learning_techniques = []
machine_learning_techniques.append(SVC())
machine_learning_techniques.append(LinearSVC())
machine_learning_techniques.append(RandomForestClassifier())
machine_learning_techniques.append(KNeighborsClassifier())
machine_learning_techniques.append(GaussianNB())
machine_learning_techniques.append(Perceptron())
machine_learning_techniques.append(SGDClassifier())
machine_learning_techniques.append(DecisionTreeClassifier())
machine_learning_techniques.append(MultinomialNB())

# %% [markdown]
# ### Embaralhar nossa amostra

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ### Treinar e avaliar nossos modelos

# %%
for tech in machine_learning_techniques:

    # cross 10-fold validation
    interval = int(len(df)/10)
    total_acc = []
    total_rmse = []
    for i in range(0, len(df)-interval, interval):

        test_df = df.loc[i:i+interval]
        if i+interval > len(df)-interval:
            test_df = df.loc[i:]

        train_df = df.drop(test_df.index)
        # Balanceamento não melhorou a predição dos modelos e por isso não foi utilizado, seguimos com a distribuição reais dos dados.
        # train_df = balancing(train_df)

        X_test = test_df.drop("quality", axis=1)
        Y_test = test_df["quality"]

        X_train = train_df.drop("quality", axis=1)
        Y_train = train_df["quality"]

        # treina
        tech.fit(X_train, Y_train)
        
        # predição e acc
        Y_pred = tech.predict(X_test)
        
        acc_tech = round(tech.score(X_test, Y_test) * 100, 2)
        mse = mean_squared_error(Y_test, Y_pred)
        # print(f'acc: {acc_tech} mse:{mse}')
        total_acc.append(acc_tech)
        total_rmse.append(mse)

    acc_mean = sum(total_acc)/len(total_acc)
    rmse_mean = sum(total_rmse)/len(total_rmse)
    print(f'acc: {round(acc_mean, 2)}% - rmse: {round(rmse_mean, 2)} {tech.__class__.__name__}')
# Out:
# acc: 54.12 - rmse: 0.65 SVC
# acc: 52.95 - rmse: 0.67 LinearSVC
# acc: 70.14 - rmse: 0.41 RandomForestClassifier
# acc: 58.07 - rmse: 0.63 KNeighborsClassifier
# acc: 2.08 - rmse: 6.52 GaussianNB
# acc: 42.5 - rmse: 1.17 Perceptron
# acc: 51.69 - rmse: 0.72 SGDClassifier
# acc: 62.88 - rmse: 0.67 DecisionTreeClassifier
# acc: 43.78 - rmse: 0.79 MultinomialNB

# %% [markdown]
# # Deep Learning

# %%
import keras
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt

from keras.utils import np_utils

# %% [markdown]
# ### Definição do modelo

# %%
model = keras.Sequential([
    keras.layers.Dense(128, activation='elu', input_shape=(13,)),
    keras.layers.Dense(64, activation='elu'),
    keras.layers.Dense(32, activation='elu'),
    keras.layers.Dense(16, activation='elu'),
    keras.layers.Dense(7, activation='softmax')
])

# %% [markdown]
# ### Criação de uma callback

# %%
from keras.callbacks import Callback

class TerminateTrainingLoss(Callback):

    """
    Termina o treino quando atinge determinada loss
    """

    def __init__(self, minimal_loss=0.2):
        self.minimal_loss = minimal_loss

    def on_epoch_end(self, epoch, logs=None, verbose=False):
        
        if logs.get('loss') < self.minimal_loss:
            self.model.stop_training = True

# %% [markdown]
# ### Criação de uma loss function para observação

# %%
def RMSE(y_true, y_pred):
    # Um pouco diferente da abordagem do sklearn por que utiliza das probabilidades da softmax 
    # (não comparável até que se utilizem a mesma abordagem para avaliação)
    return K.sqrt(K.mean(K.square(y_pred - y_true))) 

adam = keras.optimizers.Adam(learning_rate=0.004)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['acc', RMSE])

# %% [markdown]
# ### Preparação dos dados

# %%
df = df.sample(frac=1).reset_index(drop=True)
interval = int(len(df)/10)
print(f'interval: {interval}')

test_df = df.loc[:interval]
train_df = df.drop(test_df.index)
# Balanceamento não melhorou a predição dos modelos e por isso não foi utilizado, seguimos com a distribuição reais dos dados.
# train_df = balancing(train_df)

# Como parte do pré processamento vamos transformar o label em matriz identidade
# por isso vamos simplificar o valor desse resultado para um intervalo melhor aceitável
# entre 0 e 7 e não entre 3 e 9
X_test = test_df.drop("quality", axis=1)
Y_test = test_df["quality"]-3

X_train = train_df.drop("quality", axis=1)
Y_train = train_df["quality"]-3

print(np_utils.to_categorical(Y_test).shape)
# Out:
# interval: 649
# (650, 6)

# %% [markdown]
# ### Treino e avaliação do modelo

# %%
# callback
callback = TerminateTrainingLoss()

# treina
history = model.fit(X_train, 
                    np_utils.to_categorical(Y_train, num_classes=7), 
                    epochs=1000, 
                    callbacks=[callback],
                    verbose=1, 
                    batch_size=128, 
                    validation_split = 0.1)

# predição e acc e mse
_, acc_tech, _ = model.evaluate(X_test, 
                            np_utils.to_categorical(Y_test, num_classes=7), 
                            verbose=0)

print(f'\nDeep learning trouxe uma acurácia de {round(acc_tech,2)}\n')
# Out:
# Train on 5262 samples, validate on 585 samples
# Epoch 1/1000
# 5262/5262 [==============================] - 1s 199us/step - loss: 1.2607 - acc: 0.4491 - RMSE: 0.3054 - val_loss: 1.1169 - val_acc: 0.5077 - val_RMSE: 0.2933
# Epoch 2/1000
# 5262/5262 [==============================] - 0s 20us/step - loss: 1.1133 - acc: 0.5300 - RMSE: 0.2911 - val_loss: 1.0948 - val_acc: 0.5368 - val_RMSE: 0.2925
# Epoch 3/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.1071 - acc: 0.5325 - RMSE: 0.2918 - val_loss: 1.0706 - val_acc: 0.5197 - val_RMSE: 0.2904
# Epoch 4/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 1.0908 - acc: 0.5429 - RMSE: 0.2897 - val_loss: 1.0824 - val_acc: 0.5470 - val_RMSE: 0.2914
# Epoch 5/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0898 - acc: 0.5376 - RMSE: 0.2907 - val_loss: 1.0782 - val_acc: 0.5026 - val_RMSE: 0.2919
# Epoch 6/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0928 - acc: 0.5418 - RMSE: 0.2901 - val_loss: 1.0570 - val_acc: 0.5197 - val_RMSE: 0.2898
# Epoch 7/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0852 - acc: 0.5431 - RMSE: 0.2892 - val_loss: 1.0492 - val_acc: 0.5231 - val_RMSE: 0.2893
# Epoch 8/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0777 - acc: 0.5386 - RMSE: 0.2900 - val_loss: 1.0512 - val_acc: 0.5231 - val_RMSE: 0.2900
# Epoch 9/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0754 - acc: 0.5485 - RMSE: 0.2893 - val_loss: 1.0958 - val_acc: 0.5248 - val_RMSE: 0.2951
# Epoch 10/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0771 - acc: 0.5414 - RMSE: 0.2885 - val_loss: 1.0353 - val_acc: 0.5282 - val_RMSE: 0.2875
# Epoch 11/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0547 - acc: 0.5549 - RMSE: 0.2878 - val_loss: 1.0650 - val_acc: 0.5368 - val_RMSE: 0.2908
# Epoch 12/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0649 - acc: 0.5477 - RMSE: 0.2873 - val_loss: 1.0439 - val_acc: 0.5573 - val_RMSE: 0.2871
# Epoch 13/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0512 - acc: 0.5519 - RMSE: 0.2867 - val_loss: 1.0378 - val_acc: 0.5470 - val_RMSE: 0.2878
# Epoch 14/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0469 - acc: 0.5536 - RMSE: 0.2858 - val_loss: 1.0254 - val_acc: 0.5504 - val_RMSE: 0.2850
# Epoch 15/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0402 - acc: 0.5602 - RMSE: 0.2852 - val_loss: 1.0337 - val_acc: 0.5299 - val_RMSE: 0.2880
# Epoch 16/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0410 - acc: 0.5509 - RMSE: 0.2866 - val_loss: 1.0265 - val_acc: 0.5436 - val_RMSE: 0.2860
# Epoch 17/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0326 - acc: 0.5559 - RMSE: 0.2840 - val_loss: 1.0394 - val_acc: 0.5419 - val_RMSE: 0.2879
# Epoch 18/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0343 - acc: 0.5618 - RMSE: 0.2853 - val_loss: 1.0185 - val_acc: 0.5470 - val_RMSE: 0.2838
# Epoch 19/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0272 - acc: 0.5587 - RMSE: 0.2851 - val_loss: 1.0385 - val_acc: 0.5538 - val_RMSE: 0.2866
# Epoch 20/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0283 - acc: 0.5614 - RMSE: 0.2835 - val_loss: 1.0148 - val_acc: 0.5573 - val_RMSE: 0.2843
# Epoch 21/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0403 - acc: 0.5551 - RMSE: 0.2850 - val_loss: 1.0400 - val_acc: 0.5248 - val_RMSE: 0.2869
# Epoch 22/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0453 - acc: 0.5555 - RMSE: 0.2869 - val_loss: 1.0291 - val_acc: 0.5385 - val_RMSE: 0.2860
# Epoch 23/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0268 - acc: 0.5627 - RMSE: 0.2833 - val_loss: 1.0458 - val_acc: 0.5385 - val_RMSE: 0.2874
# Epoch 24/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 1.0218 - acc: 0.5648 - RMSE: 0.2833 - val_loss: 1.0429 - val_acc: 0.5299 - val_RMSE: 0.2889
# Epoch 25/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0232 - acc: 0.5576 - RMSE: 0.2838 - val_loss: 1.0166 - val_acc: 0.5607 - val_RMSE: 0.2842
# Epoch 26/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0209 - acc: 0.5591 - RMSE: 0.2835 - val_loss: 1.0388 - val_acc: 0.5231 - val_RMSE: 0.2883
# Epoch 27/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0383 - acc: 0.5580 - RMSE: 0.2857 - val_loss: 1.0211 - val_acc: 0.5521 - val_RMSE: 0.2848
# Epoch 28/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0332 - acc: 0.5601 - RMSE: 0.2845 - val_loss: 1.0133 - val_acc: 0.5521 - val_RMSE: 0.2837
# Epoch 29/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0180 - acc: 0.5597 - RMSE: 0.2833 - val_loss: 1.0248 - val_acc: 0.5504 - val_RMSE: 0.2845
# Epoch 30/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0135 - acc: 0.5684 - RMSE: 0.2823 - val_loss: 1.0423 - val_acc: 0.5299 - val_RMSE: 0.2887
# Epoch 31/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0201 - acc: 0.5582 - RMSE: 0.2834 - val_loss: 1.0021 - val_acc: 0.5573 - val_RMSE: 0.2824
# Epoch 32/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0170 - acc: 0.5654 - RMSE: 0.2830 - val_loss: 1.0328 - val_acc: 0.5487 - val_RMSE: 0.2865
# Epoch 33/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0181 - acc: 0.5616 - RMSE: 0.2836 - val_loss: 1.0358 - val_acc: 0.5538 - val_RMSE: 0.2875
# Epoch 34/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0506 - acc: 0.5540 - RMSE: 0.2861 - val_loss: 1.0171 - val_acc: 0.5538 - val_RMSE: 0.2843
# Epoch 35/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0164 - acc: 0.5623 - RMSE: 0.2831 - val_loss: 1.0112 - val_acc: 0.5607 - val_RMSE: 0.2838
# Epoch 36/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0058 - acc: 0.5659 - RMSE: 0.2824 - val_loss: 1.0123 - val_acc: 0.5692 - val_RMSE: 0.2834
# Epoch 37/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0080 - acc: 0.5684 - RMSE: 0.2823 - val_loss: 1.0044 - val_acc: 0.5692 - val_RMSE: 0.2827
# Epoch 38/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0023 - acc: 0.5726 - RMSE: 0.2825 - val_loss: 1.0012 - val_acc: 0.5726 - val_RMSE: 0.2826
# Epoch 39/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9999 - acc: 0.5703 - RMSE: 0.2811 - val_loss: 1.0268 - val_acc: 0.5504 - val_RMSE: 0.2847
# Epoch 40/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0069 - acc: 0.5663 - RMSE: 0.2835 - val_loss: 1.0163 - val_acc: 0.5402 - val_RMSE: 0.2839
# Epoch 41/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0386 - acc: 0.5547 - RMSE: 0.2869 - val_loss: 1.0248 - val_acc: 0.5709 - val_RMSE: 0.2841
# Epoch 42/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0147 - acc: 0.5616 - RMSE: 0.2838 - val_loss: 1.0081 - val_acc: 0.5521 - val_RMSE: 0.2839
# Epoch 43/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0117 - acc: 0.5620 - RMSE: 0.2834 - val_loss: 1.0202 - val_acc: 0.5709 - val_RMSE: 0.2839
# Epoch 44/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0000 - acc: 0.5673 - RMSE: 0.2814 - val_loss: 1.0002 - val_acc: 0.5709 - val_RMSE: 0.2821
# Epoch 45/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9921 - acc: 0.5730 - RMSE: 0.2805 - val_loss: 1.0341 - val_acc: 0.5607 - val_RMSE: 0.2856
# Epoch 46/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9955 - acc: 0.5694 - RMSE: 0.2814 - val_loss: 1.0148 - val_acc: 0.5521 - val_RMSE: 0.2848
# Epoch 47/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9965 - acc: 0.5684 - RMSE: 0.2815 - val_loss: 1.0124 - val_acc: 0.5692 - val_RMSE: 0.2840
# Epoch 48/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0019 - acc: 0.5696 - RMSE: 0.2813 - val_loss: 1.0151 - val_acc: 0.5538 - val_RMSE: 0.2830
# Epoch 49/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.9943 - acc: 0.5743 - RMSE: 0.2819 - val_loss: 1.0127 - val_acc: 0.5470 - val_RMSE: 0.2828
# Epoch 50/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9912 - acc: 0.5718 - RMSE: 0.2807 - val_loss: 1.0142 - val_acc: 0.5607 - val_RMSE: 0.2847
# Epoch 51/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9893 - acc: 0.5726 - RMSE: 0.2805 - val_loss: 1.0073 - val_acc: 0.5504 - val_RMSE: 0.2837
# Epoch 52/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9812 - acc: 0.5741 - RMSE: 0.2786 - val_loss: 1.0110 - val_acc: 0.5573 - val_RMSE: 0.2823
# Epoch 53/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9825 - acc: 0.5810 - RMSE: 0.2796 - val_loss: 1.0248 - val_acc: 0.5675 - val_RMSE: 0.2836
# Epoch 54/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9843 - acc: 0.5754 - RMSE: 0.2789 - val_loss: 1.0256 - val_acc: 0.5692 - val_RMSE: 0.2847
# Epoch 55/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9838 - acc: 0.5713 - RMSE: 0.2800 - val_loss: 1.0320 - val_acc: 0.5590 - val_RMSE: 0.2840
# Epoch 56/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9753 - acc: 0.5794 - RMSE: 0.2779 - val_loss: 1.0099 - val_acc: 0.5658 - val_RMSE: 0.2829
# Epoch 57/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9846 - acc: 0.5802 - RMSE: 0.2805 - val_loss: 1.0123 - val_acc: 0.5624 - val_RMSE: 0.2820
# Epoch 58/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9849 - acc: 0.5775 - RMSE: 0.2807 - val_loss: 1.0125 - val_acc: 0.5590 - val_RMSE: 0.2813
# Epoch 59/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9760 - acc: 0.5792 - RMSE: 0.2785 - val_loss: 1.0105 - val_acc: 0.5744 - val_RMSE: 0.2819
# Epoch 60/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9695 - acc: 0.5834 - RMSE: 0.2783 - val_loss: 1.0169 - val_acc: 0.5744 - val_RMSE: 0.2822
# Epoch 61/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9741 - acc: 0.5815 - RMSE: 0.2788 - val_loss: 1.0170 - val_acc: 0.5692 - val_RMSE: 0.2826
# Epoch 62/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9773 - acc: 0.5821 - RMSE: 0.2788 - val_loss: 1.0210 - val_acc: 0.5556 - val_RMSE: 0.2842
# Epoch 63/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9662 - acc: 0.5804 - RMSE: 0.2764 - val_loss: 1.0524 - val_acc: 0.5624 - val_RMSE: 0.2851
# Epoch 64/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9692 - acc: 0.5838 - RMSE: 0.2778 - val_loss: 1.0200 - val_acc: 0.5538 - val_RMSE: 0.2837
# Epoch 65/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9674 - acc: 0.5876 - RMSE: 0.2778 - val_loss: 1.0395 - val_acc: 0.5573 - val_RMSE: 0.2846
# Epoch 66/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.9677 - acc: 0.5817 - RMSE: 0.2786 - val_loss: 1.0135 - val_acc: 0.5624 - val_RMSE: 0.2816
# Epoch 67/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.9604 - acc: 0.5853 - RMSE: 0.2772 - val_loss: 1.0077 - val_acc: 0.5573 - val_RMSE: 0.2815
# Epoch 68/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9563 - acc: 0.5908 - RMSE: 0.2766 - val_loss: 1.0185 - val_acc: 0.5795 - val_RMSE: 0.2822
# Epoch 69/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.9599 - acc: 0.5880 - RMSE: 0.2767 - val_loss: 1.0409 - val_acc: 0.5624 - val_RMSE: 0.2849
# Epoch 70/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.9578 - acc: 0.5876 - RMSE: 0.2768 - val_loss: 1.0221 - val_acc: 0.5590 - val_RMSE: 0.2830
# Epoch 71/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9546 - acc: 0.5849 - RMSE: 0.2763 - val_loss: 1.0227 - val_acc: 0.5658 - val_RMSE: 0.2805
# Epoch 72/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9470 - acc: 0.5874 - RMSE: 0.2755 - val_loss: 1.0216 - val_acc: 0.5812 - val_RMSE: 0.2799
# Epoch 73/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9409 - acc: 0.5952 - RMSE: 0.2755 - val_loss: 1.0287 - val_acc: 0.5624 - val_RMSE: 0.2826
# Epoch 74/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9550 - acc: 0.5840 - RMSE: 0.2778 - val_loss: 1.0302 - val_acc: 0.5658 - val_RMSE: 0.2829
# Epoch 75/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.9453 - acc: 0.5950 - RMSE: 0.2738 - val_loss: 1.0363 - val_acc: 0.5880 - val_RMSE: 0.2827
# Epoch 76/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.9382 - acc: 0.5924 - RMSE: 0.2734 - val_loss: 1.0093 - val_acc: 0.5932 - val_RMSE: 0.2786
# Epoch 77/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9348 - acc: 0.5992 - RMSE: 0.2741 - val_loss: 1.0201 - val_acc: 0.5658 - val_RMSE: 0.2804
# Epoch 78/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9354 - acc: 0.5916 - RMSE: 0.2736 - val_loss: 1.0327 - val_acc: 0.5573 - val_RMSE: 0.2824
# Epoch 79/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9392 - acc: 0.5958 - RMSE: 0.2740 - val_loss: 1.0201 - val_acc: 0.5658 - val_RMSE: 0.2808
# Epoch 80/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9342 - acc: 0.5988 - RMSE: 0.2747 - val_loss: 1.0462 - val_acc: 0.5675 - val_RMSE: 0.2828
# Epoch 81/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9470 - acc: 0.5943 - RMSE: 0.2771 - val_loss: 1.0352 - val_acc: 0.5829 - val_RMSE: 0.2823
# Epoch 82/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9392 - acc: 0.5924 - RMSE: 0.2747 - val_loss: 1.0234 - val_acc: 0.5692 - val_RMSE: 0.2807
# Epoch 83/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.9250 - acc: 0.5962 - RMSE: 0.2731 - val_loss: 1.0523 - val_acc: 0.5556 - val_RMSE: 0.2836
# Epoch 84/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.9257 - acc: 0.6028 - RMSE: 0.2728 - val_loss: 1.0235 - val_acc: 0.5880 - val_RMSE: 0.2805
# Epoch 85/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9220 - acc: 0.6002 - RMSE: 0.2738 - val_loss: 1.0321 - val_acc: 0.5709 - val_RMSE: 0.2806
# Epoch 86/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9214 - acc: 0.5986 - RMSE: 0.2723 - val_loss: 1.0463 - val_acc: 0.5521 - val_RMSE: 0.2842
# Epoch 87/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9207 - acc: 0.6003 - RMSE: 0.2716 - val_loss: 1.0328 - val_acc: 0.5761 - val_RMSE: 0.2811
# Epoch 88/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9160 - acc: 0.6089 - RMSE: 0.2707 - val_loss: 1.0252 - val_acc: 0.5795 - val_RMSE: 0.2812
# Epoch 89/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.9084 - acc: 0.6038 - RMSE: 0.2699 - val_loss: 1.0256 - val_acc: 0.5846 - val_RMSE: 0.2794
# Epoch 90/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.9250 - acc: 0.6017 - RMSE: 0.2732 - val_loss: 1.0230 - val_acc: 0.5880 - val_RMSE: 0.2798
# Epoch 91/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.9311 - acc: 0.5983 - RMSE: 0.2731 - val_loss: 1.0360 - val_acc: 0.5761 - val_RMSE: 0.2817
# Epoch 92/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9009 - acc: 0.6121 - RMSE: 0.2697 - val_loss: 1.0329 - val_acc: 0.5658 - val_RMSE: 0.2815
# Epoch 93/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9005 - acc: 0.6100 - RMSE: 0.2688 - val_loss: 1.0463 - val_acc: 0.5487 - val_RMSE: 0.2855
# Epoch 94/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.8992 - acc: 0.6079 - RMSE: 0.2681 - val_loss: 1.0419 - val_acc: 0.5795 - val_RMSE: 0.2819
# Epoch 95/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.9101 - acc: 0.6098 - RMSE: 0.2713 - val_loss: 1.0516 - val_acc: 0.5607 - val_RMSE: 0.2839
# Epoch 96/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8976 - acc: 0.6100 - RMSE: 0.2690 - val_loss: 1.0311 - val_acc: 0.5880 - val_RMSE: 0.2816
# Epoch 97/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.8910 - acc: 0.6135 - RMSE: 0.2672 - val_loss: 1.0635 - val_acc: 0.5624 - val_RMSE: 0.2850
# Epoch 98/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.8905 - acc: 0.6176 - RMSE: 0.2671 - val_loss: 1.0675 - val_acc: 0.5573 - val_RMSE: 0.2861
# Epoch 99/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8870 - acc: 0.6233 - RMSE: 0.2667 - val_loss: 1.0676 - val_acc: 0.5556 - val_RMSE: 0.2849
# Epoch 100/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8945 - acc: 0.6112 - RMSE: 0.2683 - val_loss: 1.0565 - val_acc: 0.5829 - val_RMSE: 0.2836
# Epoch 101/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8880 - acc: 0.6163 - RMSE: 0.2682 - val_loss: 1.0618 - val_acc: 0.5726 - val_RMSE: 0.2823
# Epoch 102/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8905 - acc: 0.6209 - RMSE: 0.2668 - val_loss: 1.0559 - val_acc: 0.5624 - val_RMSE: 0.2829
# Epoch 103/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8807 - acc: 0.6195 - RMSE: 0.2670 - val_loss: 1.0479 - val_acc: 0.5692 - val_RMSE: 0.2829
# Epoch 104/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.8831 - acc: 0.6161 - RMSE: 0.2670 - val_loss: 1.0776 - val_acc: 0.5590 - val_RMSE: 0.2849
# Epoch 105/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9110 - acc: 0.6119 - RMSE: 0.2707 - val_loss: 1.0596 - val_acc: 0.5658 - val_RMSE: 0.2841
# Epoch 106/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8668 - acc: 0.6256 - RMSE: 0.2638 - val_loss: 1.0565 - val_acc: 0.5726 - val_RMSE: 0.2855
# Epoch 107/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8674 - acc: 0.6262 - RMSE: 0.2647 - val_loss: 1.0344 - val_acc: 0.5726 - val_RMSE: 0.2814
# Epoch 108/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.8698 - acc: 0.6216 - RMSE: 0.2656 - val_loss: 1.0616 - val_acc: 0.5658 - val_RMSE: 0.2862
# Epoch 109/1000
# 5262/5262 [==============================] - 0s 19us/step - loss: 0.8704 - acc: 0.6252 - RMSE: 0.2656 - val_loss: 1.0453 - val_acc: 0.5726 - val_RMSE: 0.2847
# Epoch 110/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.8672 - acc: 0.6243 - RMSE: 0.2650 - val_loss: 1.0607 - val_acc: 0.5778 - val_RMSE: 0.2844
# Epoch 111/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8624 - acc: 0.6298 - RMSE: 0.2643 - val_loss: 1.0393 - val_acc: 0.5846 - val_RMSE: 0.2800
# Epoch 112/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8680 - acc: 0.6250 - RMSE: 0.2648 - val_loss: 1.0512 - val_acc: 0.5795 - val_RMSE: 0.2820
# Epoch 113/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8507 - acc: 0.6340 - RMSE: 0.2623 - val_loss: 1.0605 - val_acc: 0.5692 - val_RMSE: 0.2860
# Epoch 114/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8491 - acc: 0.6345 - RMSE: 0.2627 - val_loss: 1.0546 - val_acc: 0.5778 - val_RMSE: 0.2833
# Epoch 115/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8486 - acc: 0.6315 - RMSE: 0.2619 - val_loss: 1.0794 - val_acc: 0.5761 - val_RMSE: 0.2848
# Epoch 116/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.8640 - acc: 0.6353 - RMSE: 0.2638 - val_loss: 1.0514 - val_acc: 0.5812 - val_RMSE: 0.2809
# Epoch 117/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.8610 - acc: 0.6313 - RMSE: 0.2649 - val_loss: 1.0451 - val_acc: 0.5897 - val_RMSE: 0.2799
# Epoch 118/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8560 - acc: 0.6294 - RMSE: 0.2636 - val_loss: 1.0490 - val_acc: 0.5795 - val_RMSE: 0.2830
# Epoch 119/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8626 - acc: 0.6249 - RMSE: 0.2638 - val_loss: 1.0432 - val_acc: 0.5829 - val_RMSE: 0.2807
# Epoch 120/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.8393 - acc: 0.6393 - RMSE: 0.2602 - val_loss: 1.0436 - val_acc: 0.5897 - val_RMSE: 0.2819
# Epoch 121/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.8406 - acc: 0.6437 - RMSE: 0.2605 - val_loss: 1.0730 - val_acc: 0.5761 - val_RMSE: 0.2839
# Epoch 122/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.8473 - acc: 0.6364 - RMSE: 0.2621 - val_loss: 1.0405 - val_acc: 0.5778 - val_RMSE: 0.2800
# Epoch 123/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8351 - acc: 0.6458 - RMSE: 0.2596 - val_loss: 1.0564 - val_acc: 0.5521 - val_RMSE: 0.2818
# Epoch 124/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8245 - acc: 0.6488 - RMSE: 0.2593 - val_loss: 1.0524 - val_acc: 0.5761 - val_RMSE: 0.2826
# Epoch 125/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8265 - acc: 0.6431 - RMSE: 0.2596 - val_loss: 1.0643 - val_acc: 0.5761 - val_RMSE: 0.2836
# Epoch 126/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8393 - acc: 0.6444 - RMSE: 0.2589 - val_loss: 1.0815 - val_acc: 0.5778 - val_RMSE: 0.2839
# Epoch 127/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8144 - acc: 0.6518 - RMSE: 0.2566 - val_loss: 1.0974 - val_acc: 0.5590 - val_RMSE: 0.2870
# Epoch 128/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8333 - acc: 0.6418 - RMSE: 0.2593 - val_loss: 1.0810 - val_acc: 0.5915 - val_RMSE: 0.2827
# Epoch 129/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8202 - acc: 0.6473 - RMSE: 0.2577 - val_loss: 1.0761 - val_acc: 0.5778 - val_RMSE: 0.2829
# Epoch 130/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8133 - acc: 0.6570 - RMSE: 0.2565 - val_loss: 1.0929 - val_acc: 0.5675 - val_RMSE: 0.2843
# Epoch 131/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8144 - acc: 0.6494 - RMSE: 0.2558 - val_loss: 1.0679 - val_acc: 0.5829 - val_RMSE: 0.2802
# Epoch 132/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8129 - acc: 0.6505 - RMSE: 0.2551 - val_loss: 1.0717 - val_acc: 0.5641 - val_RMSE: 0.2818
# Epoch 133/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7994 - acc: 0.6579 - RMSE: 0.2543 - val_loss: 1.0932 - val_acc: 0.5709 - val_RMSE: 0.2875
# Epoch 134/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8063 - acc: 0.6612 - RMSE: 0.2551 - val_loss: 1.0701 - val_acc: 0.5880 - val_RMSE: 0.2818
# Epoch 135/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.8015 - acc: 0.6536 - RMSE: 0.2541 - val_loss: 1.0748 - val_acc: 0.5932 - val_RMSE: 0.2810
# Epoch 136/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.7876 - acc: 0.6670 - RMSE: 0.2546 - val_loss: 1.0936 - val_acc: 0.5812 - val_RMSE: 0.2833
# Epoch 137/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8041 - acc: 0.6585 - RMSE: 0.2553 - val_loss: 1.1392 - val_acc: 0.5709 - val_RMSE: 0.2885
# Epoch 138/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8049 - acc: 0.6513 - RMSE: 0.2552 - val_loss: 1.0815 - val_acc: 0.5726 - val_RMSE: 0.2814
# Epoch 139/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8067 - acc: 0.6619 - RMSE: 0.2559 - val_loss: 1.0953 - val_acc: 0.5863 - val_RMSE: 0.2840
# Epoch 140/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8017 - acc: 0.6511 - RMSE: 0.2562 - val_loss: 1.0945 - val_acc: 0.5726 - val_RMSE: 0.2838
# Epoch 141/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8142 - acc: 0.6610 - RMSE: 0.2575 - val_loss: 1.0874 - val_acc: 0.5573 - val_RMSE: 0.2860
# Epoch 142/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8139 - acc: 0.6524 - RMSE: 0.2568 - val_loss: 1.0923 - val_acc: 0.5880 - val_RMSE: 0.2841
# Epoch 143/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.8154 - acc: 0.6539 - RMSE: 0.2560 - val_loss: 1.0810 - val_acc: 0.5897 - val_RMSE: 0.2805
# Epoch 144/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7912 - acc: 0.6604 - RMSE: 0.2543 - val_loss: 1.0766 - val_acc: 0.5624 - val_RMSE: 0.2827
# Epoch 145/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7799 - acc: 0.6684 - RMSE: 0.2516 - val_loss: 1.0978 - val_acc: 0.5573 - val_RMSE: 0.2847
# Epoch 146/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7909 - acc: 0.6646 - RMSE: 0.2519 - val_loss: 1.1229 - val_acc: 0.5658 - val_RMSE: 0.2851
# Epoch 147/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7855 - acc: 0.6670 - RMSE: 0.2525 - val_loss: 1.1030 - val_acc: 0.5761 - val_RMSE: 0.2822
# Epoch 148/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7676 - acc: 0.6703 - RMSE: 0.2512 - val_loss: 1.1072 - val_acc: 0.5863 - val_RMSE: 0.2836
# Epoch 149/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7669 - acc: 0.6680 - RMSE: 0.2504 - val_loss: 1.1034 - val_acc: 0.5761 - val_RMSE: 0.2827
# Epoch 150/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.7658 - acc: 0.6790 - RMSE: 0.2499 - val_loss: 1.1328 - val_acc: 0.5709 - val_RMSE: 0.2857
# Epoch 151/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7838 - acc: 0.6653 - RMSE: 0.2533 - val_loss: 1.1090 - val_acc: 0.5778 - val_RMSE: 0.2839
# Epoch 152/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7722 - acc: 0.6701 - RMSE: 0.2517 - val_loss: 1.0724 - val_acc: 0.5966 - val_RMSE: 0.2782
# Epoch 153/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7567 - acc: 0.6727 - RMSE: 0.2472 - val_loss: 1.1051 - val_acc: 0.5709 - val_RMSE: 0.2826
# Epoch 154/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.7526 - acc: 0.6745 - RMSE: 0.2476 - val_loss: 1.0834 - val_acc: 0.6171 - val_RMSE: 0.2769
# Epoch 155/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7499 - acc: 0.6798 - RMSE: 0.2477 - val_loss: 1.1245 - val_acc: 0.5966 - val_RMSE: 0.2825
# Epoch 156/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7500 - acc: 0.6845 - RMSE: 0.2481 - val_loss: 1.1576 - val_acc: 0.5863 - val_RMSE: 0.2841
# Epoch 157/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7458 - acc: 0.6790 - RMSE: 0.2476 - val_loss: 1.1108 - val_acc: 0.5641 - val_RMSE: 0.2809
# Epoch 158/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7733 - acc: 0.6737 - RMSE: 0.2506 - val_loss: 1.1400 - val_acc: 0.5812 - val_RMSE: 0.2862
# Epoch 159/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7570 - acc: 0.6784 - RMSE: 0.2498 - val_loss: 1.1206 - val_acc: 0.5880 - val_RMSE: 0.2844
# Epoch 160/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7619 - acc: 0.6811 - RMSE: 0.2489 - val_loss: 1.1517 - val_acc: 0.5795 - val_RMSE: 0.2863
# Epoch 161/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7488 - acc: 0.6811 - RMSE: 0.2488 - val_loss: 1.1287 - val_acc: 0.5761 - val_RMSE: 0.2844
# Epoch 162/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7346 - acc: 0.6914 - RMSE: 0.2441 - val_loss: 1.1250 - val_acc: 0.5863 - val_RMSE: 0.2826
# Epoch 163/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7406 - acc: 0.6880 - RMSE: 0.2454 - val_loss: 1.1531 - val_acc: 0.5863 - val_RMSE: 0.2852
# Epoch 164/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7333 - acc: 0.6883 - RMSE: 0.2441 - val_loss: 1.1518 - val_acc: 0.5778 - val_RMSE: 0.2833
# Epoch 165/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7276 - acc: 0.6885 - RMSE: 0.2442 - val_loss: 1.1525 - val_acc: 0.5846 - val_RMSE: 0.2826
# Epoch 166/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7326 - acc: 0.6885 - RMSE: 0.2443 - val_loss: 1.1438 - val_acc: 0.5897 - val_RMSE: 0.2839
# Epoch 167/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7373 - acc: 0.6821 - RMSE: 0.2455 - val_loss: 1.1592 - val_acc: 0.5607 - val_RMSE: 0.2863
# Epoch 168/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7259 - acc: 0.6942 - RMSE: 0.2445 - val_loss: 1.1495 - val_acc: 0.5795 - val_RMSE: 0.2841
# Epoch 169/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7354 - acc: 0.6864 - RMSE: 0.2460 - val_loss: 1.1499 - val_acc: 0.5607 - val_RMSE: 0.2863
# Epoch 170/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7259 - acc: 0.6946 - RMSE: 0.2438 - val_loss: 1.1279 - val_acc: 0.5863 - val_RMSE: 0.2808
# Epoch 171/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7267 - acc: 0.6923 - RMSE: 0.2445 - val_loss: 1.1507 - val_acc: 0.5863 - val_RMSE: 0.2829
# Epoch 172/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7119 - acc: 0.6982 - RMSE: 0.2423 - val_loss: 1.1716 - val_acc: 0.5863 - val_RMSE: 0.2841
# Epoch 173/1000
# 5262/5262 [==============================] - 0s 19us/step - loss: 0.7502 - acc: 0.6830 - RMSE: 0.2480 - val_loss: 1.1215 - val_acc: 0.5863 - val_RMSE: 0.2834
# Epoch 174/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.7391 - acc: 0.6813 - RMSE: 0.2455 - val_loss: 1.1382 - val_acc: 0.5709 - val_RMSE: 0.2829
# Epoch 175/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.7173 - acc: 0.6959 - RMSE: 0.2432 - val_loss: 1.1370 - val_acc: 0.5897 - val_RMSE: 0.2847
# Epoch 176/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.7267 - acc: 0.6933 - RMSE: 0.2435 - val_loss: 1.1649 - val_acc: 0.5726 - val_RMSE: 0.2860
# Epoch 177/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.7350 - acc: 0.6807 - RMSE: 0.2468 - val_loss: 1.1366 - val_acc: 0.5846 - val_RMSE: 0.2852
# Epoch 178/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.7124 - acc: 0.6925 - RMSE: 0.2419 - val_loss: 1.1379 - val_acc: 0.5829 - val_RMSE: 0.2816
# Epoch 179/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6941 - acc: 0.7009 - RMSE: 0.2387 - val_loss: 1.1648 - val_acc: 0.5778 - val_RMSE: 0.2859
# Epoch 180/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.7102 - acc: 0.6992 - RMSE: 0.2414 - val_loss: 1.1613 - val_acc: 0.5675 - val_RMSE: 0.2864
# Epoch 181/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.6916 - acc: 0.7051 - RMSE: 0.2386 - val_loss: 1.1757 - val_acc: 0.5795 - val_RMSE: 0.2874
# Epoch 182/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6966 - acc: 0.7062 - RMSE: 0.2386 - val_loss: 1.2087 - val_acc: 0.5778 - val_RMSE: 0.2889
# Epoch 183/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6976 - acc: 0.7018 - RMSE: 0.2403 - val_loss: 1.1598 - val_acc: 0.5897 - val_RMSE: 0.2854
# Epoch 184/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6969 - acc: 0.7003 - RMSE: 0.2393 - val_loss: 1.1936 - val_acc: 0.5880 - val_RMSE: 0.2846
# Epoch 185/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6929 - acc: 0.7104 - RMSE: 0.2386 - val_loss: 1.1457 - val_acc: 0.5897 - val_RMSE: 0.2800
# Epoch 186/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.7259 - acc: 0.6895 - RMSE: 0.2431 - val_loss: 1.1872 - val_acc: 0.5761 - val_RMSE: 0.2865
# Epoch 187/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7002 - acc: 0.7054 - RMSE: 0.2401 - val_loss: 1.1675 - val_acc: 0.5829 - val_RMSE: 0.2831
# Epoch 188/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7108 - acc: 0.6990 - RMSE: 0.2416 - val_loss: 1.2430 - val_acc: 0.5607 - val_RMSE: 0.2924
# Epoch 189/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7030 - acc: 0.7016 - RMSE: 0.2392 - val_loss: 1.2371 - val_acc: 0.5709 - val_RMSE: 0.2869
# Epoch 190/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6710 - acc: 0.7146 - RMSE: 0.2352 - val_loss: 1.1753 - val_acc: 0.6017 - val_RMSE: 0.2800
# Epoch 191/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7540 - acc: 0.6843 - RMSE: 0.2470 - val_loss: 1.2026 - val_acc: 0.5692 - val_RMSE: 0.2859
# Epoch 192/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.7023 - acc: 0.7054 - RMSE: 0.2396 - val_loss: 1.2023 - val_acc: 0.5761 - val_RMSE: 0.2860
# Epoch 193/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6897 - acc: 0.7106 - RMSE: 0.2376 - val_loss: 1.1617 - val_acc: 0.5863 - val_RMSE: 0.2793
# Epoch 194/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6743 - acc: 0.7119 - RMSE: 0.2359 - val_loss: 1.1771 - val_acc: 0.5880 - val_RMSE: 0.2813
# Epoch 195/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6689 - acc: 0.7189 - RMSE: 0.2339 - val_loss: 1.1751 - val_acc: 0.6034 - val_RMSE: 0.2824
# Epoch 196/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6675 - acc: 0.7166 - RMSE: 0.2345 - val_loss: 1.2055 - val_acc: 0.5949 - val_RMSE: 0.2837
# Epoch 197/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6609 - acc: 0.7195 - RMSE: 0.2332 - val_loss: 1.1873 - val_acc: 0.6034 - val_RMSE: 0.2816
# Epoch 198/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6790 - acc: 0.7165 - RMSE: 0.2361 - val_loss: 1.2066 - val_acc: 0.5863 - val_RMSE: 0.2855
# Epoch 199/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6822 - acc: 0.7127 - RMSE: 0.2380 - val_loss: 1.1743 - val_acc: 0.5812 - val_RMSE: 0.2845
# Epoch 200/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.7254 - acc: 0.6963 - RMSE: 0.2431 - val_loss: 1.2184 - val_acc: 0.5761 - val_RMSE: 0.2885
# Epoch 201/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6885 - acc: 0.6978 - RMSE: 0.2382 - val_loss: 1.2100 - val_acc: 0.5880 - val_RMSE: 0.2853
# Epoch 202/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6752 - acc: 0.7102 - RMSE: 0.2354 - val_loss: 1.2437 - val_acc: 0.5556 - val_RMSE: 0.2891
# Epoch 203/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6518 - acc: 0.7290 - RMSE: 0.2312 - val_loss: 1.2280 - val_acc: 0.5949 - val_RMSE: 0.2805
# Epoch 204/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6729 - acc: 0.7147 - RMSE: 0.2353 - val_loss: 1.2363 - val_acc: 0.5778 - val_RMSE: 0.2858
# Epoch 205/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6660 - acc: 0.7204 - RMSE: 0.2336 - val_loss: 1.2204 - val_acc: 0.5778 - val_RMSE: 0.2870
# Epoch 206/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6569 - acc: 0.7212 - RMSE: 0.2325 - val_loss: 1.2297 - val_acc: 0.5949 - val_RMSE: 0.2837
# Epoch 207/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6835 - acc: 0.7081 - RMSE: 0.2373 - val_loss: 1.1866 - val_acc: 0.5744 - val_RMSE: 0.2859
# Epoch 208/1000
# 5262/5262 [==============================] - 0s 19us/step - loss: 0.6621 - acc: 0.7241 - RMSE: 0.2334 - val_loss: 1.2119 - val_acc: 0.5863 - val_RMSE: 0.2841
# Epoch 209/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.6648 - acc: 0.7210 - RMSE: 0.2315 - val_loss: 1.2045 - val_acc: 0.5846 - val_RMSE: 0.2840
# Epoch 210/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.6605 - acc: 0.7187 - RMSE: 0.2322 - val_loss: 1.2158 - val_acc: 0.5795 - val_RMSE: 0.2861
# Epoch 211/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6416 - acc: 0.7258 - RMSE: 0.2303 - val_loss: 1.2543 - val_acc: 0.5846 - val_RMSE: 0.2888
# Epoch 212/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6529 - acc: 0.7170 - RMSE: 0.2307 - val_loss: 1.2448 - val_acc: 0.5829 - val_RMSE: 0.2888
# Epoch 213/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6345 - acc: 0.7241 - RMSE: 0.2291 - val_loss: 1.1852 - val_acc: 0.5863 - val_RMSE: 0.2830
# Epoch 214/1000
# 5262/5262 [==============================] - 0s 21us/step - loss: 0.6285 - acc: 0.7298 - RMSE: 0.2271 - val_loss: 1.2696 - val_acc: 0.5812 - val_RMSE: 0.2893
# Epoch 215/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6397 - acc: 0.7292 - RMSE: 0.2311 - val_loss: 1.2607 - val_acc: 0.5863 - val_RMSE: 0.2855
# Epoch 216/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.7181 - acc: 0.6971 - RMSE: 0.2423 - val_loss: 1.2271 - val_acc: 0.5812 - val_RMSE: 0.2875
# Epoch 217/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6575 - acc: 0.7220 - RMSE: 0.2328 - val_loss: 1.2216 - val_acc: 0.6034 - val_RMSE: 0.2859
# Epoch 218/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6379 - acc: 0.7282 - RMSE: 0.2299 - val_loss: 1.2510 - val_acc: 0.5880 - val_RMSE: 0.2871
# Epoch 219/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6410 - acc: 0.7267 - RMSE: 0.2293 - val_loss: 1.3239 - val_acc: 0.5641 - val_RMSE: 0.2936
# Epoch 220/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6382 - acc: 0.7275 - RMSE: 0.2298 - val_loss: 1.2387 - val_acc: 0.5863 - val_RMSE: 0.2856
# Epoch 221/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6539 - acc: 0.7239 - RMSE: 0.2321 - val_loss: 1.2384 - val_acc: 0.5846 - val_RMSE: 0.2861
# Epoch 222/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6316 - acc: 0.7288 - RMSE: 0.2289 - val_loss: 1.2314 - val_acc: 0.5932 - val_RMSE: 0.2857
# Epoch 223/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6402 - acc: 0.7328 - RMSE: 0.2302 - val_loss: 1.2271 - val_acc: 0.5949 - val_RMSE: 0.2870
# Epoch 224/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6431 - acc: 0.7216 - RMSE: 0.2309 - val_loss: 1.2750 - val_acc: 0.6017 - val_RMSE: 0.2867
# Epoch 225/1000
# 5262/5262 [==============================] - 0s 21us/step - loss: 0.6387 - acc: 0.7301 - RMSE: 0.2290 - val_loss: 1.1814 - val_acc: 0.5897 - val_RMSE: 0.2816
# Epoch 226/1000
# 5262/5262 [==============================] - 0s 19us/step - loss: 0.6250 - acc: 0.7338 - RMSE: 0.2267 - val_loss: 1.2232 - val_acc: 0.5966 - val_RMSE: 0.2833
# Epoch 227/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6064 - acc: 0.7404 - RMSE: 0.2251 - val_loss: 1.2649 - val_acc: 0.5915 - val_RMSE: 0.2873
# Epoch 228/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6310 - acc: 0.7328 - RMSE: 0.2288 - val_loss: 1.2371 - val_acc: 0.5863 - val_RMSE: 0.2855
# Epoch 229/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6867 - acc: 0.7075 - RMSE: 0.2346 - val_loss: 1.2956 - val_acc: 0.5829 - val_RMSE: 0.2920
# Epoch 230/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6288 - acc: 0.7336 - RMSE: 0.2274 - val_loss: 1.2926 - val_acc: 0.5932 - val_RMSE: 0.2876
# Epoch 231/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6234 - acc: 0.7349 - RMSE: 0.2270 - val_loss: 1.2490 - val_acc: 0.6017 - val_RMSE: 0.2858
# Epoch 232/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6146 - acc: 0.7353 - RMSE: 0.2259 - val_loss: 1.2668 - val_acc: 0.5812 - val_RMSE: 0.2875
# Epoch 233/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6273 - acc: 0.7353 - RMSE: 0.2259 - val_loss: 1.2702 - val_acc: 0.5949 - val_RMSE: 0.2883
# Epoch 234/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6262 - acc: 0.7320 - RMSE: 0.2245 - val_loss: 1.3044 - val_acc: 0.5966 - val_RMSE: 0.2880
# Epoch 235/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6056 - acc: 0.7450 - RMSE: 0.2235 - val_loss: 1.2473 - val_acc: 0.6017 - val_RMSE: 0.2812
# Epoch 236/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6096 - acc: 0.7425 - RMSE: 0.2235 - val_loss: 1.3402 - val_acc: 0.5726 - val_RMSE: 0.2931
# Epoch 237/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6169 - acc: 0.7395 - RMSE: 0.2251 - val_loss: 1.3069 - val_acc: 0.5915 - val_RMSE: 0.2899
# Epoch 238/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6105 - acc: 0.7374 - RMSE: 0.2239 - val_loss: 1.3293 - val_acc: 0.5897 - val_RMSE: 0.2921
# Epoch 239/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6130 - acc: 0.7328 - RMSE: 0.2259 - val_loss: 1.2846 - val_acc: 0.6017 - val_RMSE: 0.2868
# Epoch 240/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6115 - acc: 0.7400 - RMSE: 0.2258 - val_loss: 1.3368 - val_acc: 0.5846 - val_RMSE: 0.2892
# Epoch 241/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6651 - acc: 0.7199 - RMSE: 0.2336 - val_loss: 1.2992 - val_acc: 0.5812 - val_RMSE: 0.2886
# Epoch 242/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6386 - acc: 0.7267 - RMSE: 0.2288 - val_loss: 1.2975 - val_acc: 0.5795 - val_RMSE: 0.2899
# Epoch 243/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6063 - acc: 0.7412 - RMSE: 0.2242 - val_loss: 1.3842 - val_acc: 0.6000 - val_RMSE: 0.2905
# Epoch 244/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6091 - acc: 0.7408 - RMSE: 0.2237 - val_loss: 1.3310 - val_acc: 0.5812 - val_RMSE: 0.2907
# Epoch 245/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6064 - acc: 0.7444 - RMSE: 0.2230 - val_loss: 1.3160 - val_acc: 0.5846 - val_RMSE: 0.2907
# Epoch 246/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5855 - acc: 0.7471 - RMSE: 0.2199 - val_loss: 1.3040 - val_acc: 0.5949 - val_RMSE: 0.2871
# Epoch 247/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5864 - acc: 0.7491 - RMSE: 0.2194 - val_loss: 1.3424 - val_acc: 0.6068 - val_RMSE: 0.2889
# Epoch 248/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5888 - acc: 0.7501 - RMSE: 0.2195 - val_loss: 1.3521 - val_acc: 0.5863 - val_RMSE: 0.2914
# Epoch 249/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6096 - acc: 0.7395 - RMSE: 0.2247 - val_loss: 1.3670 - val_acc: 0.5846 - val_RMSE: 0.2892
# Epoch 250/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5975 - acc: 0.7467 - RMSE: 0.2201 - val_loss: 1.3693 - val_acc: 0.5966 - val_RMSE: 0.2869
# Epoch 251/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5899 - acc: 0.7469 - RMSE: 0.2202 - val_loss: 1.3586 - val_acc: 0.5983 - val_RMSE: 0.2887
# Epoch 252/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5763 - acc: 0.7577 - RMSE: 0.2188 - val_loss: 1.3358 - val_acc: 0.5812 - val_RMSE: 0.2880
# Epoch 253/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5916 - acc: 0.7503 - RMSE: 0.2217 - val_loss: 1.3626 - val_acc: 0.5778 - val_RMSE: 0.2906
# Epoch 254/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6071 - acc: 0.7368 - RMSE: 0.2229 - val_loss: 1.3114 - val_acc: 0.6017 - val_RMSE: 0.2846
# Epoch 255/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5901 - acc: 0.7459 - RMSE: 0.2206 - val_loss: 1.3479 - val_acc: 0.5863 - val_RMSE: 0.2892
# Epoch 256/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5818 - acc: 0.7520 - RMSE: 0.2190 - val_loss: 1.4329 - val_acc: 0.5795 - val_RMSE: 0.2957
# Epoch 257/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5842 - acc: 0.7472 - RMSE: 0.2203 - val_loss: 1.4314 - val_acc: 0.5880 - val_RMSE: 0.2940
# Epoch 258/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5991 - acc: 0.7429 - RMSE: 0.2225 - val_loss: 1.4144 - val_acc: 0.5709 - val_RMSE: 0.2941
# Epoch 259/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5835 - acc: 0.7535 - RMSE: 0.2189 - val_loss: 1.3760 - val_acc: 0.5897 - val_RMSE: 0.2925
# Epoch 260/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5865 - acc: 0.7548 - RMSE: 0.2195 - val_loss: 1.3858 - val_acc: 0.5915 - val_RMSE: 0.2913
# Epoch 261/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5611 - acc: 0.7571 - RMSE: 0.2167 - val_loss: 1.3594 - val_acc: 0.5949 - val_RMSE: 0.2887
# Epoch 262/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5898 - acc: 0.7545 - RMSE: 0.2193 - val_loss: 1.4477 - val_acc: 0.5709 - val_RMSE: 0.2927
# Epoch 263/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5628 - acc: 0.7588 - RMSE: 0.2167 - val_loss: 1.3867 - val_acc: 0.5932 - val_RMSE: 0.2909
# Epoch 264/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5558 - acc: 0.7664 - RMSE: 0.2132 - val_loss: 1.4729 - val_acc: 0.5949 - val_RMSE: 0.2937
# Epoch 265/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5563 - acc: 0.7630 - RMSE: 0.2137 - val_loss: 1.5549 - val_acc: 0.5761 - val_RMSE: 0.2988
# Epoch 266/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5661 - acc: 0.7585 - RMSE: 0.2172 - val_loss: 1.4253 - val_acc: 0.5915 - val_RMSE: 0.2915
# Epoch 267/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5629 - acc: 0.7600 - RMSE: 0.2158 - val_loss: 1.4629 - val_acc: 0.5863 - val_RMSE: 0.2915
# Epoch 268/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5651 - acc: 0.7607 - RMSE: 0.2167 - val_loss: 1.4337 - val_acc: 0.5966 - val_RMSE: 0.2889
# Epoch 269/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5735 - acc: 0.7562 - RMSE: 0.2177 - val_loss: 1.4756 - val_acc: 0.5915 - val_RMSE: 0.2903
# Epoch 270/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.5971 - acc: 0.7471 - RMSE: 0.2230 - val_loss: 1.5048 - val_acc: 0.5966 - val_RMSE: 0.2937
# Epoch 271/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5823 - acc: 0.7554 - RMSE: 0.2196 - val_loss: 1.4500 - val_acc: 0.6137 - val_RMSE: 0.2910
# Epoch 272/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5737 - acc: 0.7569 - RMSE: 0.2182 - val_loss: 1.4623 - val_acc: 0.5915 - val_RMSE: 0.2918
# Epoch 273/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5567 - acc: 0.7636 - RMSE: 0.2132 - val_loss: 1.5475 - val_acc: 0.5778 - val_RMSE: 0.2983
# Epoch 274/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5514 - acc: 0.7729 - RMSE: 0.2134 - val_loss: 1.4076 - val_acc: 0.5863 - val_RMSE: 0.2883
# Epoch 275/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.5534 - acc: 0.7621 - RMSE: 0.2141 - val_loss: 1.4493 - val_acc: 0.5846 - val_RMSE: 0.2910
# Epoch 276/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.5630 - acc: 0.7602 - RMSE: 0.2152 - val_loss: 1.5382 - val_acc: 0.5949 - val_RMSE: 0.2930
# Epoch 277/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5688 - acc: 0.7697 - RMSE: 0.2138 - val_loss: 1.4471 - val_acc: 0.5761 - val_RMSE: 0.2910
# Epoch 278/1000
# ...
# Epoch 909/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3091 - acc: 0.8765 - RMSE: 0.1582 - val_loss: 3.1603 - val_acc: 0.5966 - val_RMSE: 0.3082
# Epoch 910/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5385 - acc: 0.8235 - RMSE: 0.1903 - val_loss: 3.0293 - val_acc: 0.5607 - val_RMSE: 0.3145
# Epoch 911/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4388 - acc: 0.8396 - RMSE: 0.1803 - val_loss: 2.9437 - val_acc: 0.5915 - val_RMSE: 0.3075
# Epoch 912/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.3652 - acc: 0.8516 - RMSE: 0.1729 - val_loss: 2.7203 - val_acc: 0.5641 - val_RMSE: 0.3096
# Epoch 913/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.4120 - acc: 0.8307 - RMSE: 0.1799 - val_loss: 2.9042 - val_acc: 0.5829 - val_RMSE: 0.3057
# Epoch 914/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.3560 - acc: 0.8575 - RMSE: 0.1688 - val_loss: 2.8485 - val_acc: 0.5897 - val_RMSE: 0.3056
# Epoch 915/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2949 - acc: 0.8833 - RMSE: 0.1543 - val_loss: 2.8761 - val_acc: 0.5932 - val_RMSE: 0.3062
# Epoch 916/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2637 - acc: 0.8945 - RMSE: 0.1463 - val_loss: 2.8930 - val_acc: 0.6068 - val_RMSE: 0.3047
# Epoch 917/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2562 - acc: 0.8987 - RMSE: 0.1439 - val_loss: 2.8812 - val_acc: 0.5915 - val_RMSE: 0.3064
# Epoch 918/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2513 - acc: 0.8991 - RMSE: 0.1439 - val_loss: 2.9099 - val_acc: 0.5932 - val_RMSE: 0.3050
# Epoch 919/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2686 - acc: 0.8938 - RMSE: 0.1481 - val_loss: 2.9411 - val_acc: 0.6120 - val_RMSE: 0.3033
# Epoch 920/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2497 - acc: 0.8974 - RMSE: 0.1423 - val_loss: 2.9330 - val_acc: 0.5966 - val_RMSE: 0.3050
# Epoch 921/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2600 - acc: 0.8959 - RMSE: 0.1446 - val_loss: 3.0249 - val_acc: 0.5966 - val_RMSE: 0.3041
# Epoch 922/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2515 - acc: 0.9038 - RMSE: 0.1432 - val_loss: 3.0393 - val_acc: 0.5897 - val_RMSE: 0.3076
# Epoch 923/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2415 - acc: 0.9036 - RMSE: 0.1395 - val_loss: 3.1902 - val_acc: 0.5932 - val_RMSE: 0.3093
# Epoch 924/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2512 - acc: 0.9046 - RMSE: 0.1408 - val_loss: 3.0329 - val_acc: 0.5949 - val_RMSE: 0.3070
# Epoch 925/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2769 - acc: 0.8913 - RMSE: 0.1472 - val_loss: 3.0816 - val_acc: 0.6051 - val_RMSE: 0.3077
# Epoch 926/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2659 - acc: 0.8907 - RMSE: 0.1487 - val_loss: 3.2263 - val_acc: 0.5846 - val_RMSE: 0.3116
# Epoch 927/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3207 - acc: 0.8729 - RMSE: 0.1601 - val_loss: 3.2466 - val_acc: 0.5538 - val_RMSE: 0.3187
# Epoch 928/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3190 - acc: 0.8674 - RMSE: 0.1618 - val_loss: 3.2381 - val_acc: 0.5778 - val_RMSE: 0.3110
# Epoch 929/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3609 - acc: 0.8626 - RMSE: 0.1675 - val_loss: 3.2084 - val_acc: 0.5709 - val_RMSE: 0.3117
# Epoch 930/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.3497 - acc: 0.8580 - RMSE: 0.1695 - val_loss: 3.2446 - val_acc: 0.5829 - val_RMSE: 0.3146
# Epoch 931/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3683 - acc: 0.8584 - RMSE: 0.1681 - val_loss: 3.0670 - val_acc: 0.5880 - val_RMSE: 0.3118
# Epoch 932/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.4435 - acc: 0.8347 - RMSE: 0.1818 - val_loss: 2.9711 - val_acc: 0.5795 - val_RMSE: 0.3128
# Epoch 933/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3658 - acc: 0.8573 - RMSE: 0.1698 - val_loss: 2.8739 - val_acc: 0.5897 - val_RMSE: 0.3056
# Epoch 934/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3064 - acc: 0.8808 - RMSE: 0.1561 - val_loss: 2.9985 - val_acc: 0.5829 - val_RMSE: 0.3086
# Epoch 935/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2852 - acc: 0.8839 - RMSE: 0.1526 - val_loss: 3.0081 - val_acc: 0.5949 - val_RMSE: 0.3074
# Epoch 936/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2599 - acc: 0.8938 - RMSE: 0.1434 - val_loss: 3.1273 - val_acc: 0.5812 - val_RMSE: 0.3096
# Epoch 937/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2463 - acc: 0.9019 - RMSE: 0.1407 - val_loss: 3.0769 - val_acc: 0.5795 - val_RMSE: 0.3109
# Epoch 938/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2564 - acc: 0.8979 - RMSE: 0.1453 - val_loss: 3.2571 - val_acc: 0.5675 - val_RMSE: 0.3146
# Epoch 939/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.4579 - acc: 0.8407 - RMSE: 0.1828 - val_loss: 2.9969 - val_acc: 0.6034 - val_RMSE: 0.3057
# Epoch 940/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3661 - acc: 0.8596 - RMSE: 0.1675 - val_loss: 3.0272 - val_acc: 0.5795 - val_RMSE: 0.3070
# Epoch 941/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3202 - acc: 0.8746 - RMSE: 0.1613 - val_loss: 3.0196 - val_acc: 0.5795 - val_RMSE: 0.3077
# Epoch 942/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3671 - acc: 0.8630 - RMSE: 0.1686 - val_loss: 2.9566 - val_acc: 0.5761 - val_RMSE: 0.3115
# Epoch 943/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.5198 - acc: 0.8219 - RMSE: 0.1897 - val_loss: 2.9424 - val_acc: 0.5744 - val_RMSE: 0.3106
# Epoch 944/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3995 - acc: 0.8453 - RMSE: 0.1775 - val_loss: 3.0657 - val_acc: 0.5846 - val_RMSE: 0.3099
# Epoch 945/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3254 - acc: 0.8660 - RMSE: 0.1642 - val_loss: 3.0385 - val_acc: 0.6120 - val_RMSE: 0.3043
# Epoch 946/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3382 - acc: 0.8691 - RMSE: 0.1630 - val_loss: 2.9839 - val_acc: 0.5846 - val_RMSE: 0.3107
# Epoch 947/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3205 - acc: 0.8696 - RMSE: 0.1609 - val_loss: 3.1212 - val_acc: 0.6068 - val_RMSE: 0.3056
# Epoch 948/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3064 - acc: 0.8736 - RMSE: 0.1578 - val_loss: 3.0256 - val_acc: 0.6017 - val_RMSE: 0.3067
# Epoch 949/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2885 - acc: 0.8854 - RMSE: 0.1515 - val_loss: 2.9812 - val_acc: 0.6085 - val_RMSE: 0.3042
# Epoch 950/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2692 - acc: 0.8928 - RMSE: 0.1484 - val_loss: 3.1016 - val_acc: 0.5983 - val_RMSE: 0.3051
# Epoch 951/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3373 - acc: 0.8616 - RMSE: 0.1660 - val_loss: 3.0451 - val_acc: 0.5829 - val_RMSE: 0.3128
# Epoch 952/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3164 - acc: 0.8694 - RMSE: 0.1613 - val_loss: 2.9995 - val_acc: 0.6017 - val_RMSE: 0.3058
# Epoch 953/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2661 - acc: 0.8902 - RMSE: 0.1494 - val_loss: 3.0016 - val_acc: 0.6171 - val_RMSE: 0.3033
# Epoch 954/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2545 - acc: 0.8991 - RMSE: 0.1416 - val_loss: 3.1659 - val_acc: 0.5880 - val_RMSE: 0.3097
# Epoch 955/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2382 - acc: 0.9078 - RMSE: 0.1382 - val_loss: 3.1363 - val_acc: 0.6120 - val_RMSE: 0.3037
# Epoch 956/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2457 - acc: 0.9040 - RMSE: 0.1403 - val_loss: 3.1451 - val_acc: 0.5863 - val_RMSE: 0.3079
# Epoch 957/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2770 - acc: 0.8888 - RMSE: 0.1523 - val_loss: 3.1272 - val_acc: 0.5949 - val_RMSE: 0.3085
# Epoch 958/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2805 - acc: 0.8846 - RMSE: 0.1522 - val_loss: 3.2427 - val_acc: 0.5897 - val_RMSE: 0.3090
# Epoch 959/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2849 - acc: 0.8867 - RMSE: 0.1516 - val_loss: 3.3973 - val_acc: 0.5932 - val_RMSE: 0.3095
# Epoch 960/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.4462 - acc: 0.8328 - RMSE: 0.1845 - val_loss: 3.0640 - val_acc: 0.5829 - val_RMSE: 0.3116
# Epoch 961/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.4418 - acc: 0.8362 - RMSE: 0.1832 - val_loss: 2.8509 - val_acc: 0.5949 - val_RMSE: 0.3075
# Epoch 962/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.4026 - acc: 0.8463 - RMSE: 0.1776 - val_loss: 3.0123 - val_acc: 0.5897 - val_RMSE: 0.3089
# Epoch 963/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3981 - acc: 0.8501 - RMSE: 0.1746 - val_loss: 2.9425 - val_acc: 0.5675 - val_RMSE: 0.3111
# Epoch 964/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3384 - acc: 0.8679 - RMSE: 0.1651 - val_loss: 3.0103 - val_acc: 0.5778 - val_RMSE: 0.3108
# Epoch 965/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2950 - acc: 0.8879 - RMSE: 0.1537 - val_loss: 2.8446 - val_acc: 0.5966 - val_RMSE: 0.3055
# Epoch 966/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2916 - acc: 0.8835 - RMSE: 0.1531 - val_loss: 2.9541 - val_acc: 0.5915 - val_RMSE: 0.3055
# Epoch 967/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2591 - acc: 0.8960 - RMSE: 0.1446 - val_loss: 3.0665 - val_acc: 0.5897 - val_RMSE: 0.3069
# Epoch 968/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.2420 - acc: 0.9023 - RMSE: 0.1392 - val_loss: 3.1592 - val_acc: 0.6120 - val_RMSE: 0.3069
# Epoch 969/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2402 - acc: 0.9038 - RMSE: 0.1392 - val_loss: 3.1485 - val_acc: 0.6068 - val_RMSE: 0.3060
# Epoch 970/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2461 - acc: 0.8998 - RMSE: 0.1413 - val_loss: 3.1623 - val_acc: 0.5846 - val_RMSE: 0.3098
# Epoch 971/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2482 - acc: 0.9027 - RMSE: 0.1418 - val_loss: 3.2003 - val_acc: 0.6000 - val_RMSE: 0.3085
# Epoch 972/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2380 - acc: 0.9103 - RMSE: 0.1362 - val_loss: 3.0002 - val_acc: 0.5949 - val_RMSE: 0.3063
# Epoch 973/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2326 - acc: 0.9065 - RMSE: 0.1359 - val_loss: 3.2968 - val_acc: 0.6017 - val_RMSE: 0.3085
# Epoch 974/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.3139 - acc: 0.8757 - RMSE: 0.1587 - val_loss: 3.3601 - val_acc: 0.5863 - val_RMSE: 0.3133
# Epoch 975/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.4193 - acc: 0.8495 - RMSE: 0.1731 - val_loss: 3.1305 - val_acc: 0.5932 - val_RMSE: 0.3122
# Epoch 976/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2988 - acc: 0.8765 - RMSE: 0.1555 - val_loss: 3.2259 - val_acc: 0.6000 - val_RMSE: 0.3070
# Epoch 977/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2608 - acc: 0.8976 - RMSE: 0.1432 - val_loss: 3.1034 - val_acc: 0.5932 - val_RMSE: 0.3093
# Epoch 978/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2915 - acc: 0.8845 - RMSE: 0.1520 - val_loss: 3.0694 - val_acc: 0.6154 - val_RMSE: 0.3040
# Epoch 979/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2545 - acc: 0.8985 - RMSE: 0.1439 - val_loss: 3.1436 - val_acc: 0.5983 - val_RMSE: 0.3058
# Epoch 980/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2523 - acc: 0.8985 - RMSE: 0.1424 - val_loss: 3.1725 - val_acc: 0.5915 - val_RMSE: 0.3104
# Epoch 981/1000
# 5262/5262 [==============================] - 0s 10us/step - loss: 0.2432 - acc: 0.9019 - RMSE: 0.1382 - val_loss: 3.1568 - val_acc: 0.6034 - val_RMSE: 0.3035
# Epoch 982/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2334 - acc: 0.9073 - RMSE: 0.1374 - val_loss: 3.2019 - val_acc: 0.6103 - val_RMSE: 0.3093
# Epoch 983/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2658 - acc: 0.8947 - RMSE: 0.1470 - val_loss: 3.3602 - val_acc: 0.5932 - val_RMSE: 0.3131
# Epoch 984/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.6231 - acc: 0.7993 - RMSE: 0.2033 - val_loss: 3.0120 - val_acc: 0.5880 - val_RMSE: 0.3138
# Epoch 985/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.4734 - acc: 0.8252 - RMSE: 0.1888 - val_loss: 2.9891 - val_acc: 0.5744 - val_RMSE: 0.3138
# Epoch 986/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.4004 - acc: 0.8434 - RMSE: 0.1770 - val_loss: 2.9756 - val_acc: 0.5812 - val_RMSE: 0.3118
# Epoch 987/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.3534 - acc: 0.8561 - RMSE: 0.1693 - val_loss: 3.1233 - val_acc: 0.5897 - val_RMSE: 0.3090
# Epoch 988/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.3704 - acc: 0.8565 - RMSE: 0.1681 - val_loss: 3.0682 - val_acc: 0.5778 - val_RMSE: 0.3142
# Epoch 989/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2741 - acc: 0.8894 - RMSE: 0.1507 - val_loss: 3.0766 - val_acc: 0.6137 - val_RMSE: 0.3067
# Epoch 990/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.3091 - acc: 0.8776 - RMSE: 0.1593 - val_loss: 3.1111 - val_acc: 0.5966 - val_RMSE: 0.3085
# Epoch 991/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.3276 - acc: 0.8677 - RMSE: 0.1607 - val_loss: 3.1154 - val_acc: 0.6051 - val_RMSE: 0.3080
# Epoch 992/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2728 - acc: 0.8903 - RMSE: 0.1482 - val_loss: 3.1437 - val_acc: 0.6068 - val_RMSE: 0.3056
# Epoch 993/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2685 - acc: 0.8926 - RMSE: 0.1510 - val_loss: 3.1202 - val_acc: 0.5761 - val_RMSE: 0.3112
# Epoch 994/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.3154 - acc: 0.8719 - RMSE: 0.1587 - val_loss: 3.2055 - val_acc: 0.5744 - val_RMSE: 0.3123
# Epoch 995/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2787 - acc: 0.8896 - RMSE: 0.1493 - val_loss: 3.3351 - val_acc: 0.5949 - val_RMSE: 0.3117
# Epoch 996/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2659 - acc: 0.8960 - RMSE: 0.1471 - val_loss: 3.1972 - val_acc: 0.5983 - val_RMSE: 0.3082
# Epoch 997/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2517 - acc: 0.8976 - RMSE: 0.1445 - val_loss: 3.1223 - val_acc: 0.6120 - val_RMSE: 0.3047
# Epoch 998/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2422 - acc: 0.9073 - RMSE: 0.1393 - val_loss: 3.2450 - val_acc: 0.5829 - val_RMSE: 0.3126
# Epoch 999/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.2741 - acc: 0.8955 - RMSE: 0.1469 - val_loss: 3.1206 - val_acc: 0.5897 - val_RMSE: 0.3075
# Epoch 1000/1000
# 5262/5262 [==============================] - 0s 11us/step - loss: 0.4228 - acc: 0.8504 - RMSE: 0.1732 - val_loss: 3.0930 - val_acc: 0.5812 - val_RMSE: 0.3123
#
# Deep learning trouxe uma acurácia de 0.58

# %% [markdown]
# ### Vamos plotar o histórico de treinamento

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation mse values
plt.plot(history.history['RMSE'])
plt.plot(history.history['val_RMSE'])
plt.title('Model mse')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

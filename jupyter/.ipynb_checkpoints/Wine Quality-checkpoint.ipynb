# %% [markdown]
# # Modelagem dos dados

# %%
import math
import keras
import numpy as np
import pandas as pd
import seaborn as sns

from scipy import stats
from sklearn import preprocessing
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Leitura dos dados

# %%
df = pd.read_csv("./../winequality.csv", sep=";")
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  White            7.0              0.27         0.36            20.7
# 1  White            6.3              0.30         0.34             1.6
# 2  White            8.1              0.28         0.40             6.9
# 3  White            7.2              0.23         0.32             8.5
# 4  White            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates alcohol  quality
# 0       0.45     8.8        6
# 1       0.49     9.5        6
# 2       0.44    10.1        6
# 3       0.40     9.9        6
# 4       0.40     9.9        6

# %% [markdown]
# ### Vejamos os tipos de dados de cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   object
#  12  quality               6497 non-null   int64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 660.0+ KB

# %% [markdown]
# ### TRATAMENTO DO BANCO DE DADOS
#
# Se observado os dados type e alcohol são objects, precisamos só trabalhar com números.
#
# * type: object (vamos mudar para inteiro)
# * alcohol: object (vamos mudar para float e eliminar dados incosistentes)

# %%
#adicionar números como representantes das categorias
df['type'] = df['type'].map( {'White': 1, 'Red': 0} ).astype(int)
#vamos corrigir os erros da coluna, e substituí-los para NaN, em seguida preencher essas lacunas com a moda
#poderiamos ignorá-los, mas cada dado é valioso e vamos investigar usando essas dados corrompidos
df['alcohol'] = pd.to_numeric(df['alcohol'], errors='coerce')
freq_port = df.alcohol.dropna().mode()[0]
df['alcohol'] = df['alcohol'].fillna(freq_port)

# %% [markdown]
# ### Agora os dados são apenas números!!!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   int64
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
# vamos remover a informação de qualidade para normalizar, depois vamos recoloca-la
quality_serie = df['quality']
df = df[:-1]
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      1.0       0.206612          0.166667     0.120482        0.265337
# 1      1.0       0.198347          0.106667     0.162651        0.248466
# 2      1.0       0.181818          0.233333     0.204819        0.107362
# 3      1.0       0.247934          0.066667     0.168675        0.141104
# 4      0.0       0.280992          0.360000     0.036145        0.032209
# ...    ...            ...               ...          ...             ...
# 6491   1.0       0.231405          0.143333     0.144578        0.015337
# 6492   0.0       0.421488          0.443333     0.108434        0.029141
# 6493   1.0       0.289256          0.093333     0.156627        0.013804
# 6494   0.0       0.380165          0.393333     0.114458        0.024540
# 6495   1.0       0.272727          0.066667     0.192771        0.177914
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# 0      0.094684             0.121528              0.357143        0  0.325581
# 1      0.051495             0.163194              0.283410        0  0.395349
# 2      0.059801             0.083333              0.258065        0  0.240310
# 3      0.049834             0.097222              0.246544        0  0.302326
# 4      0.112957             0.048611              0.182028        0  0.612403
# ...         ...                  ...                   ...      ...       ...
# 6491   0.049834             0.097222              0.308756        0  0.488372
# 6492   0.112957             0.048611              0.096774        0  0.372093
# 6493   0.051495             0.107639              0.382488        0  0.426357
# 6494   0.139535             0.034722              0.158986        0  0.372093
# 6495   0.064784             0.121528              0.274194        0  0.155039
#
#       sulphates   alcohol  quality  prop dioxide
# 0      0.162921  0.115942        5      0.240738
# 1      0.089888  0.362319        6      0.418695
# 2      0.084270  0.434783        6      0.226670
# 3      0.129213  0.420290        7      0.280328
# 4      0.179775  0.217391        5      0.184253
# ...         ...       ...      ...           ...
# 6491   0.219101  0.347826        7      0.221012
# 6492   0.140449  0.246377        6      0.347276
# 6493   0.146067  0.463768        6      0.195729
# 6494   0.207865  0.173913        4      0.148534
# 6495   0.179775  0.202899        6      0.317914
#
# [6496 rows x 14 columns]

# %% [markdown]
# ### Esse é um caso interessante, vamos adicionar um atributo relacionado a proporção de dioxide, adicionado como joy example para mostrar que algumas derivações de atributos foram avaliadas. Foi percebido essa possibilidade no final da análise, porém o melhor momento de adicionar é antes da normalização.

# %%
# Adiciono uma nova variável com a proporção de dioxide
df['prop dioxide'] = df['free sulfur dioxide']/df['total sulfur dioxide']

ax2 = df.plot.scatter(x='free sulfur dioxide',
                      y='total sulfur dioxide',
                      c='quality',
                      colormap='viridis')

# %%
ax3 = sns.boxplot(x="quality", y="prop dioxide", data=df)

# %% [markdown]
# ### Para começar a análise, vamos ver como a distribuição dos dados se dá

# %%
df.boxplot(column=list(df.columns))

# %% [markdown]
# ### Percebe-se que alguns atributos tem valores discrepantes, para melhorar essa visualização e não enviesar nossos modelos (alguns podem ser enviesados por essa discrepâcia de valores), vamos normalizar esses dados.

# %%
x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled, columns=df.columns)
df = df_normalized

df.boxplot(column=list(df.columns))

# %% [markdown]
# ### Como podem ver, alguns atributos tem outliers, vamos remove-los.

# %%
#REMOVER OUTLIERS
z_scores = stats.zscore(df) #calculate z-scores of `df` média 0 desvio padrão 1
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df_without_outliers = df[filtered_entries]

df_without_outliers.boxplot(column=list(df.columns))

# %%
df['quality'] = quality_serie
df_without_outliers[['quality', 'type']].groupby(['quality'], as_index=False).mean().sort_values(by='quality', ascending=False)
# Out:
#    quality      type
# 4        8  0.939560
# 3        7  0.856299
# 2        6  0.816248
# 1        5  0.720352
# 0        4  0.836957

# %% [markdown]
# ### Ao remover os outliers, percebemos que os dados de qualidade 3 e 9 são removidos, então eles são relevantes e devem permanecer junto com os dados.
#
# ### Agora vamos ver como o atributo quality está distribuido na coluna type novamente, mas com outra perspectiva.

# %%
df[['quality', 'type']].groupby(['quality'], as_index=False).mean().sort_values(by='quality', ascending=False)
# Out:
#    quality      type
# 6        9  1.000000
# 5        8  0.906736
# 4        7  0.815570
# 3        6  0.775035
# 2        5  0.681478
# 1        4  0.754630
# 0        3  0.666667

# %% [markdown]
# ### Atributo type parece mostrar que a incidência de vinhos de qualidade maior estão mais presentes no vinho branco. Isso se deve também a quantidade de vinhos Brancos que são sua maioria.
#
# ### Vamos interpretar atributo por atributo.

# %%
ax = sns.violinplot(x="quality", y="fixed acidity", data=df)

# %% [markdown]
# ### Esse atributo não parece ser muito descritivo porém, para os casos de qualidade 3 e 9, eles se dirvegem com uma barriga maior (maior frequência dos dados) nos vinhos de alta qualidade.
#
# ### Vamos ao próximo atributo.

# %%
ax = sns.boxplot(x="quality", y="volatile acidity", data=df)

# %% [markdown]
# ### Esse atributo já mostrou uma variedada correlacionada a qualidade, apesar de pouca.
#
# ### Interessante atributo, correlação decrescente
#
# ### Vamos ao próximo:

# %%
ax = sns.boxplot(x="quality", y="citric acid", data=df)

# %% [markdown]
# ### Isoladamente não parece um bom atributo, mas podemos ver quando ele se combina com outro, sempre que isso ocorre, separamos esses casos para aumentar ou diminuir a dimensionalidade e verificar correlações, por enquanto mantemos.
#
# ### Segue o residual sugar

# %%
ax = sns.boxplot(x="quality", y="residual sugar", data=df)

# %% [markdown]
# ### Mesma situação do anterior citric acid

# %%
ax = sns.boxplot(x="quality", y="chlorides", data=df)

# %% [markdown]
# ### Sutilmente os vinhos com mais qualidade estão em um intervalo mais curto

# %%
ax = sns.boxplot(x="quality", y="free sulfur dioxide", data=df)

# %% [markdown]
# ### Sutil correlação decrescente e estreitamento do intervalo em vinhos com mais qualidade.

# %%
ax = sns.boxplot(x="quality", y="total sulfur dioxide", data=df)

# %% [markdown]
# ### Algumas características só aparecem em vinhos com qualidade inferior, o intervalo fica mais concentrados a medida que a qualidade aumenta.

# %%
ax = sns.violinplot(x="quality", y="density", data=df)

# %% [markdown]
# ### Variação inconsistente, os valores aparecem sem seguir crescente estável, nesses casos vamos categorizar por alguns intervalos.

# %%
# vamos categorizar, agrupar alguns intervalos
df.loc[ df['density'] <= 0.2, 'density'] = 0
df.loc[(df['density'] > 0.2) & (df['density'] <= 0.6), 'density'] = 0.5
df.loc[ df['density'] > 0.6, 'density'] = 1
df['density'] = df['density'].astype(int)
df[['quality', 'density']].groupby(['quality'], as_index=False).mean().sort_values(by='quality', ascending=False)
# Out:
#    quality   density
# 6        9  0.000000
# 5        8  0.000000
# 4        7  0.002780
# 3        6  0.005289
# 2        5  0.008887
# 1        4  0.004630
# 0        3  0.000000

# %% [markdown]
# ### Vinhos com densidade maior são representados com pior qualidade, com algumas exceções, inclusivo para os vinhos de pior qualidade, o que dificulta na discriminação da amostra.
#
# ### Vamos a próxima característica:

# %%
ax = sns.violinplot(x="quality", y="pH", data=df)

# %% [markdown]
# ### Quanto maior a qualidade, mais restrito são os valores aceitáveis de ph do vinho
#
# ### Vamos a próxima característica:

# %%
ax = sns.boxplot(x="quality", y="sulphates", data=df)

# %% [markdown]
# ### Não parece ser um bom atributo, porém delimita subconjuntos simples (3 e 9), (7 e 8) e (4, 5 e 6)

# %%
ax = sns.boxplot(x="quality", y="alcohol", data=df)

# %% [markdown]
# ### Ótimo atributo, mostra-se bom representante para bons vinhos
#
# ### Agora vamos separar os atributos ruins e intercala-los com outros atributos para ver se encontra algum padrão para representar bons vinhos:
#
# ### Vamos começar com

# %%
ax2 = df.plot.scatter(x='citric acid',
                      y='chlorides',
                      c='quality',
                      colormap='viridis')

# %% [markdown]
# ### Isoladamente não parece um bom preditor, mas quando combinado com chlorides, parece ter algum potencial, ver-se que os melhores qualificados vinhos estão na parte inferior do gráfico, apesar de sutil.

# %%
ax2 = df.plot.scatter(x='residual sugar',
                      y='chlorides',
                      c='quality',
                      colormap='viridis')

# %% [markdown]
# ### Isoladamente não parece um bom preditor, mas quando combinado com chlorides, um sutil correlação acontece. Quanto mais distante da região inferior esquerda, menor a qualidade do vinho.
#
# ### Assim, pelo que foi analisado, vamos manter todos os atributos com o acréscimo de mais um.

# %% [markdown]
# # Machine Learning

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Vamos selecionar nossas técnicas

# %%
machine_learning_techniques = []
machine_learning_techniques.append(SVC())
machine_learning_techniques.append(LinearSVC())
machine_learning_techniques.append(RandomForestClassifier())
machine_learning_techniques.append(KNeighborsClassifier())
machine_learning_techniques.append(GaussianNB())
machine_learning_techniques.append(Perceptron())
machine_learning_techniques.append(SGDClassifier())
machine_learning_techniques.append(DecisionTreeClassifier())
machine_learning_techniques.append(MultinomialNB())

# %% [markdown]
# ### Embaralhar nossa amostra

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ### Treinar e avaliar nossos modelos

# %%
for tech in machine_learning_techniques:

    # cross 10-fold validation
    interval = int(len(df)/10)
    total_acc = []
    total_rmse = []
    for i in range(0, len(df)-interval, interval):

        test_df = df.loc[i:i+interval]
        if i+interval > len(df)-interval:
            test_df = df.loc[i:]

        train_df = df.drop(test_df.index)
        # Balanceamento não melhorou a predição dos modelos e por isso não foi utilizado, seguimos com a distribuição reais dos dados.
        # train_df = balancing(train_df)

        X_test = test_df.drop("quality", axis=1)
        Y_test = test_df["quality"]

        X_train = train_df.drop("quality", axis=1)
        Y_train = train_df["quality"]

        # treina
        tech.fit(X_train, Y_train)
        
        # predição e acc
        Y_pred = tech.predict(X_test)
        
        acc_tech = round(tech.score(X_test, Y_test) * 100, 2)
        mse = mean_squared_error(Y_test, Y_pred)
        # print(f'acc: {acc_tech} mse:{mse}')
        total_acc.append(acc_tech)
        total_rmse.append(mse)

    acc_mean = sum(total_acc)/len(total_acc)
    rmse_mean = sum(total_rmse)/len(total_rmse)
    print(f'acc: {round(acc_mean, 2)}% - rmse: {round(rmse_mean, 2)} {tech.__class__.__name__}')
# Out:
# acc: 54.78% - rmse: 0.63 SVC
# acc: 53.38% - rmse: 0.66 LinearSVC
# acc: 70.1% - rmse: 0.41 RandomForestClassifier
# acc: 56.55% - rmse: 0.65 KNeighborsClassifier
# acc: 1.97% - rmse: 6.55 GaussianNB
# acc: 42.01% - rmse: 1.27 Perceptron
# acc: 51.64% - rmse: 0.71 SGDClassifier
# acc: 63.25% - rmse: 0.64 DecisionTreeClassifier
# acc: 43.85% - rmse: 0.79 MultinomialNB

# %% [markdown]
# # Deep Learning

# %%
import keras
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt

from keras.utils import np_utils

# %% [markdown]
# ### Definição do modelo

# %%
model = keras.Sequential([
    keras.layers.Dense(128, activation='elu', input_shape=(13,)),
    keras.layers.Dense(64, activation='elu'),
    keras.layers.Dense(32, activation='elu'),
    keras.layers.Dense(16, activation='elu'),
    keras.layers.Dense(7, activation='softmax')
])

# %% [markdown]
# ### Criação de uma callback

# %%
from keras.callbacks import Callback

class TerminateTrainingLoss(Callback):

    """
    Termina o treino quando atinge determinada loss
    """

    def __init__(self, minimal_loss=0.2):
        self.minimal_loss = minimal_loss

    def on_epoch_end(self, epoch, logs=None, verbose=False):
        
        if logs.get('loss') < self.minimal_loss:
            self.model.stop_training = True

# %% [markdown]
# ### Criação de uma loss function para observação

# %%
def RMSE(y_true, y_pred):
    # Um pouco diferente da abordagem do sklearn por que utiliza das probabilidades da softmax 
    # (não comparável até que se utilizem a mesma abordagem para avaliação)
    return K.sqrt(K.mean(K.square(y_pred - y_true))) 

adam = keras.optimizers.Adam(learning_rate=0.004)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['acc', RMSE])

# %% [markdown]
# ### Preparação dos dados

# %%
df = df.sample(frac=1).reset_index(drop=True)
interval = int(len(df)/10)
print(f'interval: {interval}')

test_df = df.loc[:interval]
train_df = df.drop(test_df.index)
# Balanceamento não melhorou a predição dos modelos e por isso não foi utilizado, seguimos com a distribuição reais dos dados.
# train_df = balancing(train_df)

# Como parte do pré processamento vamos transformar o label em matriz identidade
# por isso vamos simplificar o valor desse resultado para um intervalo melhor aceitável
# entre 0 e 7 e não entre 3 e 9
X_test = test_df.drop("quality", axis=1)
Y_test = test_df["quality"]-3

X_train = train_df.drop("quality", axis=1)
Y_train = train_df["quality"]-3

print(np_utils.to_categorical(Y_test).shape)
# Out:
# interval: 649
# (650, 6)

# %% [markdown]
# ### Treino e avaliação do modelo

# %%
# callback
callback = TerminateTrainingLoss()

# treina
history = model.fit(X_train, 
                    np_utils.to_categorical(Y_train, num_classes=7), 
                    epochs=1000, 
                    callbacks=[callback],
                    verbose=1, 
                    batch_size=128, 
                    validation_split = 0.1)

# predição e acc e mse
_, acc_tech, _ = model.evaluate(X_test, 
                            np_utils.to_categorical(Y_test, num_classes=7), 
                            verbose=0)

print(f'\nDeep learning trouxe uma acurácia de {round(acc_tech,2)}\n')
# Out:
# Train on 5262 samples, validate on 585 samples
# Epoch 1/1000
# 5262/5262 [==============================] - 0s 42us/step - loss: 1.2760 - acc: 0.4709 - RMSE: 0.3045 - val_loss: 1.1724 - val_acc: 0.5077 - val_RMSE: 0.2982
# Epoch 2/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.1183 - acc: 0.5255 - RMSE: 0.2931 - val_loss: 1.1372 - val_acc: 0.5402 - val_RMSE: 0.2942
# Epoch 3/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0971 - acc: 0.5327 - RMSE: 0.2915 - val_loss: 1.1212 - val_acc: 0.5419 - val_RMSE: 0.2934
# Epoch 4/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0999 - acc: 0.5205 - RMSE: 0.2923 - val_loss: 1.1550 - val_acc: 0.5060 - val_RMSE: 0.2974
# Epoch 5/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0973 - acc: 0.5258 - RMSE: 0.2918 - val_loss: 1.1200 - val_acc: 0.5060 - val_RMSE: 0.2947
# Epoch 6/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0806 - acc: 0.5367 - RMSE: 0.2882 - val_loss: 1.1082 - val_acc: 0.5521 - val_RMSE: 0.2909
# Epoch 7/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0887 - acc: 0.5327 - RMSE: 0.2901 - val_loss: 1.1123 - val_acc: 0.5385 - val_RMSE: 0.2930
# Epoch 8/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0766 - acc: 0.5371 - RMSE: 0.2902 - val_loss: 1.1058 - val_acc: 0.5470 - val_RMSE: 0.2914
# Epoch 9/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0791 - acc: 0.5348 - RMSE: 0.2893 - val_loss: 1.1178 - val_acc: 0.5265 - val_RMSE: 0.2930
# Epoch 10/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0754 - acc: 0.5295 - RMSE: 0.2896 - val_loss: 1.1056 - val_acc: 0.5350 - val_RMSE: 0.2910
# Epoch 11/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0694 - acc: 0.5365 - RMSE: 0.2890 - val_loss: 1.0789 - val_acc: 0.5453 - val_RMSE: 0.2885
# Epoch 12/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0644 - acc: 0.5353 - RMSE: 0.2881 - val_loss: 1.0958 - val_acc: 0.5624 - val_RMSE: 0.2905
# Epoch 13/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0566 - acc: 0.5452 - RMSE: 0.2879 - val_loss: 1.0958 - val_acc: 0.5470 - val_RMSE: 0.2915
# Epoch 14/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0567 - acc: 0.5452 - RMSE: 0.2869 - val_loss: 1.0976 - val_acc: 0.5470 - val_RMSE: 0.2900
# Epoch 15/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0490 - acc: 0.5418 - RMSE: 0.2876 - val_loss: 1.0912 - val_acc: 0.5538 - val_RMSE: 0.2891
# Epoch 16/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0472 - acc: 0.5498 - RMSE: 0.2875 - val_loss: 1.0771 - val_acc: 0.5641 - val_RMSE: 0.2894
# Epoch 17/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0470 - acc: 0.5490 - RMSE: 0.2872 - val_loss: 1.0616 - val_acc: 0.5692 - val_RMSE: 0.2855
# Epoch 18/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 1.0468 - acc: 0.5471 - RMSE: 0.2872 - val_loss: 1.0683 - val_acc: 0.5607 - val_RMSE: 0.2875
# Epoch 19/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0423 - acc: 0.5433 - RMSE: 0.2858 - val_loss: 1.0755 - val_acc: 0.5607 - val_RMSE: 0.2878
# Epoch 20/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0361 - acc: 0.5500 - RMSE: 0.2853 - val_loss: 1.0592 - val_acc: 0.5624 - val_RMSE: 0.2866
# Epoch 21/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0449 - acc: 0.5513 - RMSE: 0.2869 - val_loss: 1.0644 - val_acc: 0.5744 - val_RMSE: 0.2871
# Epoch 22/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0365 - acc: 0.5563 - RMSE: 0.2868 - val_loss: 1.0774 - val_acc: 0.5504 - val_RMSE: 0.2889
# Epoch 23/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0371 - acc: 0.5500 - RMSE: 0.2860 - val_loss: 1.0584 - val_acc: 0.5641 - val_RMSE: 0.2862
# Epoch 24/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0306 - acc: 0.5572 - RMSE: 0.2849 - val_loss: 1.0622 - val_acc: 0.5692 - val_RMSE: 0.2858
# Epoch 25/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0267 - acc: 0.5566 - RMSE: 0.2849 - val_loss: 1.0563 - val_acc: 0.5795 - val_RMSE: 0.2869
# Epoch 26/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0265 - acc: 0.5563 - RMSE: 0.2846 - val_loss: 1.0409 - val_acc: 0.5778 - val_RMSE: 0.2839
# Epoch 27/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0251 - acc: 0.5534 - RMSE: 0.2847 - val_loss: 1.0428 - val_acc: 0.5880 - val_RMSE: 0.2847
# Epoch 28/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0256 - acc: 0.5570 - RMSE: 0.2845 - val_loss: 1.0850 - val_acc: 0.5607 - val_RMSE: 0.2877
# Epoch 29/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0247 - acc: 0.5553 - RMSE: 0.2849 - val_loss: 1.0948 - val_acc: 0.5350 - val_RMSE: 0.2898
# Epoch 30/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0229 - acc: 0.5538 - RMSE: 0.2847 - val_loss: 1.0370 - val_acc: 0.5846 - val_RMSE: 0.2831
# Epoch 31/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0202 - acc: 0.5627 - RMSE: 0.2848 - val_loss: 1.0509 - val_acc: 0.5641 - val_RMSE: 0.2858
# Epoch 32/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0158 - acc: 0.5521 - RMSE: 0.2843 - val_loss: 1.0511 - val_acc: 0.5641 - val_RMSE: 0.2858
# Epoch 33/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0140 - acc: 0.5652 - RMSE: 0.2846 - val_loss: 1.0422 - val_acc: 0.5744 - val_RMSE: 0.2845
# Epoch 34/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0196 - acc: 0.5589 - RMSE: 0.2834 - val_loss: 1.0469 - val_acc: 0.5761 - val_RMSE: 0.2853
# Epoch 35/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0168 - acc: 0.5631 - RMSE: 0.2831 - val_loss: 1.0274 - val_acc: 0.5812 - val_RMSE: 0.2831
# Epoch 36/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 1.0082 - acc: 0.5623 - RMSE: 0.2821 - val_loss: 1.0449 - val_acc: 0.5812 - val_RMSE: 0.2845
# Epoch 37/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0016 - acc: 0.5658 - RMSE: 0.2816 - val_loss: 1.0505 - val_acc: 0.5658 - val_RMSE: 0.2865
# Epoch 38/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0051 - acc: 0.5610 - RMSE: 0.2824 - val_loss: 1.0378 - val_acc: 0.5744 - val_RMSE: 0.2851
# Epoch 39/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0062 - acc: 0.5627 - RMSE: 0.2835 - val_loss: 1.0709 - val_acc: 0.5761 - val_RMSE: 0.2871
# Epoch 40/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 1.0084 - acc: 0.5629 - RMSE: 0.2832 - val_loss: 1.0713 - val_acc: 0.5538 - val_RMSE: 0.2881
# Epoch 41/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 1.0080 - acc: 0.5589 - RMSE: 0.2836 - val_loss: 1.0372 - val_acc: 0.5641 - val_RMSE: 0.2839
# Epoch 42/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9926 - acc: 0.5690 - RMSE: 0.2809 - val_loss: 1.0520 - val_acc: 0.5641 - val_RMSE: 0.2855
# Epoch 43/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9945 - acc: 0.5720 - RMSE: 0.2807 - val_loss: 1.0347 - val_acc: 0.5607 - val_RMSE: 0.2849
# Epoch 44/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9940 - acc: 0.5686 - RMSE: 0.2821 - val_loss: 1.1039 - val_acc: 0.5214 - val_RMSE: 0.2932
# Epoch 45/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 1.0025 - acc: 0.5633 - RMSE: 0.2825 - val_loss: 1.0539 - val_acc: 0.5692 - val_RMSE: 0.2854
# Epoch 46/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9911 - acc: 0.5726 - RMSE: 0.2810 - val_loss: 1.0515 - val_acc: 0.5641 - val_RMSE: 0.2855
# Epoch 47/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9989 - acc: 0.5675 - RMSE: 0.2814 - val_loss: 1.0522 - val_acc: 0.5299 - val_RMSE: 0.2866
# Epoch 48/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9823 - acc: 0.5735 - RMSE: 0.2798 - val_loss: 1.0508 - val_acc: 0.5487 - val_RMSE: 0.2859
# Epoch 49/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9812 - acc: 0.5705 - RMSE: 0.2811 - val_loss: 1.0677 - val_acc: 0.5692 - val_RMSE: 0.2869
# Epoch 50/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9877 - acc: 0.5789 - RMSE: 0.2795 - val_loss: 1.0541 - val_acc: 0.5419 - val_RMSE: 0.2874
# Epoch 51/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9791 - acc: 0.5726 - RMSE: 0.2801 - val_loss: 1.0602 - val_acc: 0.5538 - val_RMSE: 0.2879
# Epoch 52/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9830 - acc: 0.5705 - RMSE: 0.2799 - val_loss: 1.0542 - val_acc: 0.5556 - val_RMSE: 0.2875
# Epoch 53/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9796 - acc: 0.5741 - RMSE: 0.2796 - val_loss: 1.0681 - val_acc: 0.5521 - val_RMSE: 0.2888
# Epoch 54/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9646 - acc: 0.5808 - RMSE: 0.2776 - val_loss: 1.0525 - val_acc: 0.5761 - val_RMSE: 0.2855
# Epoch 55/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9678 - acc: 0.5810 - RMSE: 0.2797 - val_loss: 1.0740 - val_acc: 0.5265 - val_RMSE: 0.2886
# Epoch 56/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9846 - acc: 0.5709 - RMSE: 0.2797 - val_loss: 1.0501 - val_acc: 0.5726 - val_RMSE: 0.2853
# Epoch 57/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9638 - acc: 0.5821 - RMSE: 0.2784 - val_loss: 1.0407 - val_acc: 0.5556 - val_RMSE: 0.2850
# Epoch 58/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9588 - acc: 0.5819 - RMSE: 0.2776 - val_loss: 1.0649 - val_acc: 0.5795 - val_RMSE: 0.2859
# Epoch 59/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9584 - acc: 0.5859 - RMSE: 0.2779 - val_loss: 1.0634 - val_acc: 0.5487 - val_RMSE: 0.2874
# Epoch 60/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9657 - acc: 0.5781 - RMSE: 0.2787 - val_loss: 1.0768 - val_acc: 0.5248 - val_RMSE: 0.2897
# Epoch 61/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9589 - acc: 0.5836 - RMSE: 0.2783 - val_loss: 1.0563 - val_acc: 0.5675 - val_RMSE: 0.2860
# Epoch 62/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9612 - acc: 0.5772 - RMSE: 0.2785 - val_loss: 1.0638 - val_acc: 0.5607 - val_RMSE: 0.2866
# Epoch 63/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9666 - acc: 0.5749 - RMSE: 0.2789 - val_loss: 1.0741 - val_acc: 0.5692 - val_RMSE: 0.2865
# Epoch 64/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9613 - acc: 0.5766 - RMSE: 0.2783 - val_loss: 1.0463 - val_acc: 0.5521 - val_RMSE: 0.2864
# Epoch 65/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9465 - acc: 0.5855 - RMSE: 0.2772 - val_loss: 1.0632 - val_acc: 0.5573 - val_RMSE: 0.2880
# Epoch 66/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9514 - acc: 0.5827 - RMSE: 0.2777 - val_loss: 1.0762 - val_acc: 0.5316 - val_RMSE: 0.2903
# Epoch 67/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9509 - acc: 0.5846 - RMSE: 0.2762 - val_loss: 1.0910 - val_acc: 0.5282 - val_RMSE: 0.2901
# Epoch 68/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9466 - acc: 0.5791 - RMSE: 0.2768 - val_loss: 1.0810 - val_acc: 0.5726 - val_RMSE: 0.2879
# Epoch 69/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9384 - acc: 0.5920 - RMSE: 0.2753 - val_loss: 1.0919 - val_acc: 0.5709 - val_RMSE: 0.2873
# Epoch 70/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9415 - acc: 0.5912 - RMSE: 0.2749 - val_loss: 1.0793 - val_acc: 0.5556 - val_RMSE: 0.2876
# Epoch 71/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9434 - acc: 0.5886 - RMSE: 0.2763 - val_loss: 1.0949 - val_acc: 0.5504 - val_RMSE: 0.2895
# Epoch 72/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9352 - acc: 0.5870 - RMSE: 0.2745 - val_loss: 1.1043 - val_acc: 0.5385 - val_RMSE: 0.2913
# Epoch 73/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9253 - acc: 0.5922 - RMSE: 0.2735 - val_loss: 1.0825 - val_acc: 0.5590 - val_RMSE: 0.2871
# Epoch 74/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9314 - acc: 0.5918 - RMSE: 0.2736 - val_loss: 1.0881 - val_acc: 0.5641 - val_RMSE: 0.2884
# Epoch 75/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9372 - acc: 0.5922 - RMSE: 0.2752 - val_loss: 1.0790 - val_acc: 0.5538 - val_RMSE: 0.2878
# Epoch 76/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9203 - acc: 0.5941 - RMSE: 0.2733 - val_loss: 1.0723 - val_acc: 0.5453 - val_RMSE: 0.2881
# Epoch 77/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9267 - acc: 0.5969 - RMSE: 0.2744 - val_loss: 1.0703 - val_acc: 0.5641 - val_RMSE: 0.2875
# Epoch 78/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9344 - acc: 0.5903 - RMSE: 0.2741 - val_loss: 1.0773 - val_acc: 0.5641 - val_RMSE: 0.2877
# Epoch 79/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9163 - acc: 0.5946 - RMSE: 0.2717 - val_loss: 1.0925 - val_acc: 0.5521 - val_RMSE: 0.2878
# Epoch 80/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.9099 - acc: 0.5986 - RMSE: 0.2720 - val_loss: 1.0740 - val_acc: 0.5624 - val_RMSE: 0.2862
# Epoch 81/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9191 - acc: 0.6032 - RMSE: 0.2732 - val_loss: 1.0917 - val_acc: 0.5419 - val_RMSE: 0.2893
# Epoch 82/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9098 - acc: 0.5996 - RMSE: 0.2713 - val_loss: 1.0871 - val_acc: 0.5470 - val_RMSE: 0.2894
# Epoch 83/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9056 - acc: 0.5988 - RMSE: 0.2710 - val_loss: 1.0720 - val_acc: 0.5778 - val_RMSE: 0.2848
# Epoch 84/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9067 - acc: 0.6062 - RMSE: 0.2713 - val_loss: 1.0675 - val_acc: 0.5709 - val_RMSE: 0.2868
# Epoch 85/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9177 - acc: 0.5990 - RMSE: 0.2728 - val_loss: 1.0945 - val_acc: 0.5453 - val_RMSE: 0.2891
# Epoch 86/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9022 - acc: 0.6045 - RMSE: 0.2698 - val_loss: 1.0697 - val_acc: 0.5641 - val_RMSE: 0.2872
# Epoch 87/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8895 - acc: 0.6127 - RMSE: 0.2681 - val_loss: 1.1172 - val_acc: 0.5470 - val_RMSE: 0.2924
# Epoch 88/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8924 - acc: 0.6059 - RMSE: 0.2693 - val_loss: 1.0925 - val_acc: 0.5368 - val_RMSE: 0.2912
# Epoch 89/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8962 - acc: 0.6040 - RMSE: 0.2697 - val_loss: 1.0708 - val_acc: 0.5470 - val_RMSE: 0.2864
# Epoch 90/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8804 - acc: 0.6142 - RMSE: 0.2682 - val_loss: 1.0846 - val_acc: 0.5573 - val_RMSE: 0.2872
# Epoch 91/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8697 - acc: 0.6207 - RMSE: 0.2646 - val_loss: 1.1201 - val_acc: 0.5726 - val_RMSE: 0.2899
# Epoch 92/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8860 - acc: 0.6036 - RMSE: 0.2696 - val_loss: 1.0932 - val_acc: 0.5402 - val_RMSE: 0.2892
# Epoch 93/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.9002 - acc: 0.6100 - RMSE: 0.2693 - val_loss: 1.0887 - val_acc: 0.5128 - val_RMSE: 0.2909
# Epoch 94/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8806 - acc: 0.6209 - RMSE: 0.2658 - val_loss: 1.0805 - val_acc: 0.5350 - val_RMSE: 0.2895
# Epoch 95/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8726 - acc: 0.6163 - RMSE: 0.2657 - val_loss: 1.1109 - val_acc: 0.5282 - val_RMSE: 0.2926
# Epoch 96/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8791 - acc: 0.6195 - RMSE: 0.2659 - val_loss: 1.0885 - val_acc: 0.5504 - val_RMSE: 0.2871
# Epoch 97/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8627 - acc: 0.6211 - RMSE: 0.2651 - val_loss: 1.0917 - val_acc: 0.5556 - val_RMSE: 0.2874
# Epoch 98/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8724 - acc: 0.6216 - RMSE: 0.2672 - val_loss: 1.1009 - val_acc: 0.5385 - val_RMSE: 0.2896
# Epoch 99/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.8704 - acc: 0.6205 - RMSE: 0.2649 - val_loss: 1.0745 - val_acc: 0.5607 - val_RMSE: 0.2852
# Epoch 100/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8708 - acc: 0.6212 - RMSE: 0.2660 - val_loss: 1.0778 - val_acc: 0.5641 - val_RMSE: 0.2857
# Epoch 101/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8715 - acc: 0.6207 - RMSE: 0.2662 - val_loss: 1.0672 - val_acc: 0.5675 - val_RMSE: 0.2850
# Epoch 102/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8542 - acc: 0.6269 - RMSE: 0.2648 - val_loss: 1.0906 - val_acc: 0.5692 - val_RMSE: 0.2889
# Epoch 103/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8560 - acc: 0.6288 - RMSE: 0.2641 - val_loss: 1.0876 - val_acc: 0.5658 - val_RMSE: 0.2867
# Epoch 104/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8482 - acc: 0.6271 - RMSE: 0.2626 - val_loss: 1.0857 - val_acc: 0.5624 - val_RMSE: 0.2857
# Epoch 105/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8452 - acc: 0.6317 - RMSE: 0.2629 - val_loss: 1.1014 - val_acc: 0.5658 - val_RMSE: 0.2872
# Epoch 106/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8323 - acc: 0.6427 - RMSE: 0.2606 - val_loss: 1.1179 - val_acc: 0.5402 - val_RMSE: 0.2897
# Epoch 107/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8507 - acc: 0.6313 - RMSE: 0.2639 - val_loss: 1.1032 - val_acc: 0.5470 - val_RMSE: 0.2909
# Epoch 108/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8421 - acc: 0.6342 - RMSE: 0.2621 - val_loss: 1.1236 - val_acc: 0.5470 - val_RMSE: 0.2898
# Epoch 109/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8543 - acc: 0.6279 - RMSE: 0.2628 - val_loss: 1.0989 - val_acc: 0.5846 - val_RMSE: 0.2864
# Epoch 110/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8371 - acc: 0.6399 - RMSE: 0.2600 - val_loss: 1.1230 - val_acc: 0.5265 - val_RMSE: 0.2915
# Epoch 111/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8354 - acc: 0.6340 - RMSE: 0.2606 - val_loss: 1.1145 - val_acc: 0.5573 - val_RMSE: 0.2890
# Epoch 112/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8249 - acc: 0.6454 - RMSE: 0.2574 - val_loss: 1.1155 - val_acc: 0.5504 - val_RMSE: 0.2895
# Epoch 113/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8250 - acc: 0.6439 - RMSE: 0.2586 - val_loss: 1.1119 - val_acc: 0.5556 - val_RMSE: 0.2875
# Epoch 114/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8206 - acc: 0.6452 - RMSE: 0.2588 - val_loss: 1.1264 - val_acc: 0.5726 - val_RMSE: 0.2882
# Epoch 115/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8172 - acc: 0.6446 - RMSE: 0.2583 - val_loss: 1.1224 - val_acc: 0.5709 - val_RMSE: 0.2879
# Epoch 116/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8197 - acc: 0.6480 - RMSE: 0.2589 - val_loss: 1.1092 - val_acc: 0.5880 - val_RMSE: 0.2868
# Epoch 117/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8414 - acc: 0.6446 - RMSE: 0.2601 - val_loss: 1.0950 - val_acc: 0.5897 - val_RMSE: 0.2842
# Epoch 118/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8188 - acc: 0.6471 - RMSE: 0.2573 - val_loss: 1.0961 - val_acc: 0.5692 - val_RMSE: 0.2857
# Epoch 119/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8096 - acc: 0.6486 - RMSE: 0.2575 - val_loss: 1.0995 - val_acc: 0.5624 - val_RMSE: 0.2880
# Epoch 120/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8096 - acc: 0.6494 - RMSE: 0.2568 - val_loss: 1.1198 - val_acc: 0.5983 - val_RMSE: 0.2839
# Epoch 121/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8064 - acc: 0.6541 - RMSE: 0.2567 - val_loss: 1.1242 - val_acc: 0.5573 - val_RMSE: 0.2888
# Epoch 122/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7968 - acc: 0.6579 - RMSE: 0.2559 - val_loss: 1.1409 - val_acc: 0.5795 - val_RMSE: 0.2882
# Epoch 123/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7970 - acc: 0.6585 - RMSE: 0.2561 - val_loss: 1.1482 - val_acc: 0.5778 - val_RMSE: 0.2891
# Epoch 124/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.7911 - acc: 0.6625 - RMSE: 0.2542 - val_loss: 1.1305 - val_acc: 0.5521 - val_RMSE: 0.2891
# Epoch 125/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7966 - acc: 0.6558 - RMSE: 0.2541 - val_loss: 1.1312 - val_acc: 0.5744 - val_RMSE: 0.2886
# Epoch 126/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7823 - acc: 0.6678 - RMSE: 0.2533 - val_loss: 1.1601 - val_acc: 0.5624 - val_RMSE: 0.2898
# Epoch 127/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8062 - acc: 0.6598 - RMSE: 0.2562 - val_loss: 1.1195 - val_acc: 0.5709 - val_RMSE: 0.2880
# Epoch 128/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8133 - acc: 0.6537 - RMSE: 0.2575 - val_loss: 1.1658 - val_acc: 0.5487 - val_RMSE: 0.2917
# Epoch 129/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7925 - acc: 0.6665 - RMSE: 0.2532 - val_loss: 1.1123 - val_acc: 0.5897 - val_RMSE: 0.2864
# Epoch 130/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7712 - acc: 0.6716 - RMSE: 0.2505 - val_loss: 1.1365 - val_acc: 0.5675 - val_RMSE: 0.2873
# Epoch 131/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7791 - acc: 0.6678 - RMSE: 0.2525 - val_loss: 1.1627 - val_acc: 0.5453 - val_RMSE: 0.2938
# Epoch 132/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.8013 - acc: 0.6568 - RMSE: 0.2555 - val_loss: 1.1549 - val_acc: 0.5504 - val_RMSE: 0.2907
# Epoch 133/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.7671 - acc: 0.6784 - RMSE: 0.2494 - val_loss: 1.1776 - val_acc: 0.5607 - val_RMSE: 0.2907
# Epoch 134/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7667 - acc: 0.6758 - RMSE: 0.2503 - val_loss: 1.1874 - val_acc: 0.5607 - val_RMSE: 0.2918
# Epoch 135/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7703 - acc: 0.6657 - RMSE: 0.2504 - val_loss: 1.1492 - val_acc: 0.5863 - val_RMSE: 0.2873
# Epoch 136/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7534 - acc: 0.6813 - RMSE: 0.2479 - val_loss: 1.1593 - val_acc: 0.5675 - val_RMSE: 0.2900
# Epoch 137/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7603 - acc: 0.6771 - RMSE: 0.2488 - val_loss: 1.1700 - val_acc: 0.5487 - val_RMSE: 0.2934
# Epoch 138/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7559 - acc: 0.6786 - RMSE: 0.2478 - val_loss: 1.1497 - val_acc: 0.5607 - val_RMSE: 0.2886
# Epoch 139/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7787 - acc: 0.6708 - RMSE: 0.2521 - val_loss: 1.1450 - val_acc: 0.5983 - val_RMSE: 0.2871
# Epoch 140/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7636 - acc: 0.6769 - RMSE: 0.2506 - val_loss: 1.1748 - val_acc: 0.5641 - val_RMSE: 0.2897
# Epoch 141/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7468 - acc: 0.6861 - RMSE: 0.2477 - val_loss: 1.1381 - val_acc: 0.5709 - val_RMSE: 0.2893
# Epoch 142/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7472 - acc: 0.6840 - RMSE: 0.2471 - val_loss: 1.1974 - val_acc: 0.5658 - val_RMSE: 0.2903
# Epoch 143/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7600 - acc: 0.6784 - RMSE: 0.2485 - val_loss: 1.1716 - val_acc: 0.5709 - val_RMSE: 0.2892
# Epoch 144/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7528 - acc: 0.6798 - RMSE: 0.2466 - val_loss: 1.2237 - val_acc: 0.5778 - val_RMSE: 0.2905
# Epoch 145/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7243 - acc: 0.7009 - RMSE: 0.2423 - val_loss: 1.2102 - val_acc: 0.5897 - val_RMSE: 0.2914
# Epoch 146/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7397 - acc: 0.6876 - RMSE: 0.2453 - val_loss: 1.2179 - val_acc: 0.5880 - val_RMSE: 0.2908
# Epoch 147/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7591 - acc: 0.6821 - RMSE: 0.2473 - val_loss: 1.2035 - val_acc: 0.5556 - val_RMSE: 0.2911
# Epoch 148/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7304 - acc: 0.6914 - RMSE: 0.2428 - val_loss: 1.2114 - val_acc: 0.5761 - val_RMSE: 0.2886
# Epoch 149/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.7176 - acc: 0.7007 - RMSE: 0.2411 - val_loss: 1.1946 - val_acc: 0.5846 - val_RMSE: 0.2871
# Epoch 150/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7380 - acc: 0.6855 - RMSE: 0.2446 - val_loss: 1.2477 - val_acc: 0.5350 - val_RMSE: 0.2962
# Epoch 151/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7223 - acc: 0.6923 - RMSE: 0.2417 - val_loss: 1.2214 - val_acc: 0.5641 - val_RMSE: 0.2945
# Epoch 152/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7094 - acc: 0.6982 - RMSE: 0.2403 - val_loss: 1.2963 - val_acc: 0.5333 - val_RMSE: 0.2976
# Epoch 153/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7408 - acc: 0.6870 - RMSE: 0.2461 - val_loss: 1.2416 - val_acc: 0.5658 - val_RMSE: 0.2936
# Epoch 154/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.7172 - acc: 0.6984 - RMSE: 0.2408 - val_loss: 1.2392 - val_acc: 0.5863 - val_RMSE: 0.2904
# Epoch 155/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6997 - acc: 0.7104 - RMSE: 0.2375 - val_loss: 1.2185 - val_acc: 0.5692 - val_RMSE: 0.2917
# Epoch 156/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7043 - acc: 0.7056 - RMSE: 0.2382 - val_loss: 1.2817 - val_acc: 0.5761 - val_RMSE: 0.2936
# Epoch 157/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.7043 - acc: 0.7039 - RMSE: 0.2372 - val_loss: 1.2327 - val_acc: 0.5778 - val_RMSE: 0.2913
# Epoch 158/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.6888 - acc: 0.7108 - RMSE: 0.2364 - val_loss: 1.2415 - val_acc: 0.5624 - val_RMSE: 0.2911
# Epoch 159/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.7073 - acc: 0.7041 - RMSE: 0.2395 - val_loss: 1.2579 - val_acc: 0.5692 - val_RMSE: 0.2921
# Epoch 160/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.7034 - acc: 0.7041 - RMSE: 0.2388 - val_loss: 1.2716 - val_acc: 0.5812 - val_RMSE: 0.2915
# Epoch 161/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6866 - acc: 0.7130 - RMSE: 0.2355 - val_loss: 1.2508 - val_acc: 0.5726 - val_RMSE: 0.2914
# Epoch 162/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.6942 - acc: 0.7037 - RMSE: 0.2380 - val_loss: 1.2399 - val_acc: 0.5744 - val_RMSE: 0.2915
# Epoch 163/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6831 - acc: 0.7153 - RMSE: 0.2354 - val_loss: 1.2740 - val_acc: 0.5590 - val_RMSE: 0.2945
# Epoch 164/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6815 - acc: 0.7159 - RMSE: 0.2352 - val_loss: 1.2954 - val_acc: 0.5795 - val_RMSE: 0.2934
# Epoch 165/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6956 - acc: 0.7119 - RMSE: 0.2363 - val_loss: 1.2576 - val_acc: 0.5897 - val_RMSE: 0.2902
# Epoch 166/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6849 - acc: 0.7146 - RMSE: 0.2348 - val_loss: 1.2871 - val_acc: 0.5829 - val_RMSE: 0.2942
# Epoch 167/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6802 - acc: 0.7119 - RMSE: 0.2359 - val_loss: 1.2506 - val_acc: 0.5812 - val_RMSE: 0.2908
# Epoch 168/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6669 - acc: 0.7235 - RMSE: 0.2327 - val_loss: 1.3324 - val_acc: 0.5726 - val_RMSE: 0.2950
# Epoch 169/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6668 - acc: 0.7248 - RMSE: 0.2332 - val_loss: 1.2625 - val_acc: 0.5692 - val_RMSE: 0.2931
# Epoch 170/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6969 - acc: 0.7043 - RMSE: 0.2385 - val_loss: 1.3119 - val_acc: 0.5692 - val_RMSE: 0.2920
# Epoch 171/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6631 - acc: 0.7223 - RMSE: 0.2324 - val_loss: 1.3532 - val_acc: 0.5624 - val_RMSE: 0.2970
# Epoch 172/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6765 - acc: 0.7142 - RMSE: 0.2338 - val_loss: 1.3096 - val_acc: 0.5573 - val_RMSE: 0.2978
# Epoch 173/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6592 - acc: 0.7292 - RMSE: 0.2308 - val_loss: 1.3420 - val_acc: 0.5778 - val_RMSE: 0.2929
# Epoch 174/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6664 - acc: 0.7210 - RMSE: 0.2334 - val_loss: 1.3328 - val_acc: 0.5949 - val_RMSE: 0.2914
# Epoch 175/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6684 - acc: 0.7294 - RMSE: 0.2314 - val_loss: 1.3673 - val_acc: 0.5573 - val_RMSE: 0.2957
# Epoch 176/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6573 - acc: 0.7273 - RMSE: 0.2310 - val_loss: 1.3583 - val_acc: 0.5795 - val_RMSE: 0.2937
# Epoch 177/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6587 - acc: 0.7241 - RMSE: 0.2315 - val_loss: 1.2823 - val_acc: 0.5709 - val_RMSE: 0.2929
# Epoch 178/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6607 - acc: 0.7330 - RMSE: 0.2296 - val_loss: 1.3523 - val_acc: 0.5675 - val_RMSE: 0.2954
# Epoch 179/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6697 - acc: 0.7193 - RMSE: 0.2321 - val_loss: 1.3544 - val_acc: 0.5556 - val_RMSE: 0.2943
# Epoch 180/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6460 - acc: 0.7334 - RMSE: 0.2296 - val_loss: 1.3441 - val_acc: 0.5641 - val_RMSE: 0.2930
# Epoch 181/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.6909 - acc: 0.7163 - RMSE: 0.2339 - val_loss: 1.2730 - val_acc: 0.5949 - val_RMSE: 0.2881
# Epoch 182/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6560 - acc: 0.7309 - RMSE: 0.2298 - val_loss: 1.3328 - val_acc: 0.5692 - val_RMSE: 0.2951
# Epoch 183/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6392 - acc: 0.7338 - RMSE: 0.2284 - val_loss: 1.3551 - val_acc: 0.5624 - val_RMSE: 0.2951
# Epoch 184/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6546 - acc: 0.7281 - RMSE: 0.2304 - val_loss: 1.3595 - val_acc: 0.5607 - val_RMSE: 0.2988
# Epoch 185/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6571 - acc: 0.7309 - RMSE: 0.2304 - val_loss: 1.3830 - val_acc: 0.5641 - val_RMSE: 0.2982
# Epoch 186/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6479 - acc: 0.7336 - RMSE: 0.2295 - val_loss: 1.3088 - val_acc: 0.5846 - val_RMSE: 0.2918
# Epoch 187/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6425 - acc: 0.7368 - RMSE: 0.2284 - val_loss: 1.3585 - val_acc: 0.5897 - val_RMSE: 0.2937
# Epoch 188/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6424 - acc: 0.7319 - RMSE: 0.2274 - val_loss: 1.3855 - val_acc: 0.5709 - val_RMSE: 0.2934
# Epoch 189/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6442 - acc: 0.7339 - RMSE: 0.2286 - val_loss: 1.3802 - val_acc: 0.5932 - val_RMSE: 0.2920
# Epoch 190/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6611 - acc: 0.7254 - RMSE: 0.2310 - val_loss: 1.3928 - val_acc: 0.5521 - val_RMSE: 0.2985
# Epoch 191/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6206 - acc: 0.7478 - RMSE: 0.2224 - val_loss: 1.3853 - val_acc: 0.5675 - val_RMSE: 0.2950
# Epoch 192/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6266 - acc: 0.7402 - RMSE: 0.2252 - val_loss: 1.4232 - val_acc: 0.5556 - val_RMSE: 0.2977
# Epoch 193/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6211 - acc: 0.7463 - RMSE: 0.2250 - val_loss: 1.4046 - val_acc: 0.5607 - val_RMSE: 0.2964
# Epoch 194/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6292 - acc: 0.7396 - RMSE: 0.2268 - val_loss: 1.4413 - val_acc: 0.5726 - val_RMSE: 0.2961
# Epoch 195/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6305 - acc: 0.7395 - RMSE: 0.2261 - val_loss: 1.3850 - val_acc: 0.5744 - val_RMSE: 0.2940
# Epoch 196/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6205 - acc: 0.7507 - RMSE: 0.2240 - val_loss: 1.3895 - val_acc: 0.5675 - val_RMSE: 0.2951
# Epoch 197/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.6519 - acc: 0.7292 - RMSE: 0.2298 - val_loss: 1.3657 - val_acc: 0.5880 - val_RMSE: 0.2911
# Epoch 198/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6138 - acc: 0.7421 - RMSE: 0.2234 - val_loss: 1.4598 - val_acc: 0.5538 - val_RMSE: 0.3008
# Epoch 199/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6198 - acc: 0.7488 - RMSE: 0.2241 - val_loss: 1.4253 - val_acc: 0.5726 - val_RMSE: 0.2962
# Epoch 200/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6121 - acc: 0.7503 - RMSE: 0.2235 - val_loss: 1.3969 - val_acc: 0.5675 - val_RMSE: 0.2937
# Epoch 201/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6133 - acc: 0.7482 - RMSE: 0.2223 - val_loss: 1.3967 - val_acc: 0.5744 - val_RMSE: 0.2963
# Epoch 202/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6018 - acc: 0.7495 - RMSE: 0.2209 - val_loss: 1.4071 - val_acc: 0.5778 - val_RMSE: 0.2948
# Epoch 203/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.5936 - acc: 0.7585 - RMSE: 0.2187 - val_loss: 1.4404 - val_acc: 0.5846 - val_RMSE: 0.2949
# Epoch 204/1000
# 5262/5262 [==============================] - 0s 12us/step - loss: 0.6065 - acc: 0.7476 - RMSE: 0.2214 - val_loss: 1.5271 - val_acc: 0.5658 - val_RMSE: 0.3012
# Epoch 205/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6029 - acc: 0.7522 - RMSE: 0.2215 - val_loss: 1.4287 - val_acc: 0.5709 - val_RMSE: 0.2958
# Epoch 206/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5926 - acc: 0.7558 - RMSE: 0.2195 - val_loss: 1.4934 - val_acc: 0.5795 - val_RMSE: 0.2985
# Epoch 207/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5991 - acc: 0.7569 - RMSE: 0.2224 - val_loss: 1.4931 - val_acc: 0.5658 - val_RMSE: 0.2982
# Epoch 208/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.6340 - acc: 0.7360 - RMSE: 0.2254 - val_loss: 1.4966 - val_acc: 0.5692 - val_RMSE: 0.2988
# Epoch 209/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5934 - acc: 0.7556 - RMSE: 0.2175 - val_loss: 1.5396 - val_acc: 0.5761 - val_RMSE: 0.2964
# Epoch 210/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5860 - acc: 0.7592 - RMSE: 0.2177 - val_loss: 1.4915 - val_acc: 0.5949 - val_RMSE: 0.2953
# Epoch 211/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5978 - acc: 0.7554 - RMSE: 0.2215 - val_loss: 1.5532 - val_acc: 0.5453 - val_RMSE: 0.3020
# Epoch 212/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.5933 - acc: 0.7573 - RMSE: 0.2172 - val_loss: 1.5388 - val_acc: 0.5487 - val_RMSE: 0.3036
# Epoch 213/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5780 - acc: 0.7636 - RMSE: 0.2168 - val_loss: 1.4742 - val_acc: 0.5692 - val_RMSE: 0.2968
# Epoch 214/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5819 - acc: 0.7634 - RMSE: 0.2169 - val_loss: 1.5793 - val_acc: 0.5538 - val_RMSE: 0.3027
# Epoch 215/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5956 - acc: 0.7512 - RMSE: 0.2182 - val_loss: 1.5245 - val_acc: 0.5607 - val_RMSE: 0.2988
# Epoch 216/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5573 - acc: 0.7782 - RMSE: 0.2130 - val_loss: 1.5265 - val_acc: 0.5897 - val_RMSE: 0.2990
# Epoch 217/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5949 - acc: 0.7543 - RMSE: 0.2189 - val_loss: 1.5625 - val_acc: 0.5573 - val_RMSE: 0.3047
# Epoch 218/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5992 - acc: 0.7579 - RMSE: 0.2192 - val_loss: 1.5545 - val_acc: 0.5761 - val_RMSE: 0.2995
# Epoch 219/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5721 - acc: 0.7672 - RMSE: 0.2159 - val_loss: 1.5387 - val_acc: 0.5829 - val_RMSE: 0.2936
# Epoch 220/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.6044 - acc: 0.7480 - RMSE: 0.2210 - val_loss: 1.5728 - val_acc: 0.5846 - val_RMSE: 0.2970
# Epoch 221/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5691 - acc: 0.7653 - RMSE: 0.2142 - val_loss: 1.5729 - val_acc: 0.6017 - val_RMSE: 0.2948
# Epoch 222/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5593 - acc: 0.7729 - RMSE: 0.2120 - val_loss: 1.5614 - val_acc: 0.5487 - val_RMSE: 0.3059
# Epoch 223/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.5530 - acc: 0.7676 - RMSE: 0.2095 - val_loss: 1.6102 - val_acc: 0.6000 - val_RMSE: 0.2954
# Epoch 224/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5504 - acc: 0.7731 - RMSE: 0.2102 - val_loss: 1.5917 - val_acc: 0.5726 - val_RMSE: 0.3002
# Epoch 225/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5528 - acc: 0.7796 - RMSE: 0.2111 - val_loss: 1.6322 - val_acc: 0.5744 - val_RMSE: 0.2993
# Epoch 226/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5503 - acc: 0.7826 - RMSE: 0.2107 - val_loss: 1.6211 - val_acc: 0.5624 - val_RMSE: 0.2981
# Epoch 227/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5672 - acc: 0.7695 - RMSE: 0.2146 - val_loss: 1.6135 - val_acc: 0.5863 - val_RMSE: 0.2954
# Epoch 228/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5780 - acc: 0.7615 - RMSE: 0.2168 - val_loss: 1.5610 - val_acc: 0.5880 - val_RMSE: 0.2971
# Epoch 229/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5604 - acc: 0.7714 - RMSE: 0.2115 - val_loss: 1.6010 - val_acc: 0.5692 - val_RMSE: 0.2987
# Epoch 230/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5515 - acc: 0.7803 - RMSE: 0.2111 - val_loss: 1.5897 - val_acc: 0.5709 - val_RMSE: 0.2986
# Epoch 231/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5718 - acc: 0.7674 - RMSE: 0.2155 - val_loss: 1.6710 - val_acc: 0.5573 - val_RMSE: 0.3019
# Epoch 232/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.6004 - acc: 0.7571 - RMSE: 0.2188 - val_loss: 1.6464 - val_acc: 0.5624 - val_RMSE: 0.2995
# Epoch 233/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5662 - acc: 0.7617 - RMSE: 0.2144 - val_loss: 1.6988 - val_acc: 0.5675 - val_RMSE: 0.3006
# Epoch 234/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5472 - acc: 0.7761 - RMSE: 0.2107 - val_loss: 1.6348 - val_acc: 0.5846 - val_RMSE: 0.2987
# Epoch 235/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5421 - acc: 0.7796 - RMSE: 0.2096 - val_loss: 1.6482 - val_acc: 0.5692 - val_RMSE: 0.2993
# Epoch 236/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.5415 - acc: 0.7805 - RMSE: 0.2085 - val_loss: 1.6974 - val_acc: 0.5624 - val_RMSE: 0.2990
# Epoch 237/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5593 - acc: 0.7689 - RMSE: 0.2114 - val_loss: 1.6645 - val_acc: 0.5829 - val_RMSE: 0.2982
# Epoch 238/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5435 - acc: 0.7839 - RMSE: 0.2093 - val_loss: 1.6727 - val_acc: 0.5863 - val_RMSE: 0.2985
# Epoch 239/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5582 - acc: 0.7680 - RMSE: 0.2119 - val_loss: 1.6708 - val_acc: 0.5761 - val_RMSE: 0.2977
# Epoch 240/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5656 - acc: 0.7695 - RMSE: 0.2147 - val_loss: 1.6737 - val_acc: 0.5726 - val_RMSE: 0.2998
# Epoch 241/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5617 - acc: 0.7706 - RMSE: 0.2130 - val_loss: 1.6843 - val_acc: 0.5761 - val_RMSE: 0.2992
# Epoch 242/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5226 - acc: 0.7873 - RMSE: 0.2039 - val_loss: 1.7218 - val_acc: 0.5487 - val_RMSE: 0.3047
# Epoch 243/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5207 - acc: 0.7900 - RMSE: 0.2044 - val_loss: 1.6860 - val_acc: 0.5744 - val_RMSE: 0.2988
# Epoch 244/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5188 - acc: 0.7953 - RMSE: 0.2031 - val_loss: 1.7258 - val_acc: 0.5778 - val_RMSE: 0.3012
# Epoch 245/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5181 - acc: 0.7911 - RMSE: 0.2037 - val_loss: 1.7200 - val_acc: 0.5795 - val_RMSE: 0.2985
# Epoch 246/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5282 - acc: 0.7826 - RMSE: 0.2074 - val_loss: 1.7549 - val_acc: 0.5453 - val_RMSE: 0.3068
# Epoch 247/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5522 - acc: 0.7771 - RMSE: 0.2096 - val_loss: 1.7162 - val_acc: 0.5607 - val_RMSE: 0.3057
# Epoch 248/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5399 - acc: 0.7816 - RMSE: 0.2094 - val_loss: 1.7605 - val_acc: 0.5778 - val_RMSE: 0.2982
# Epoch 249/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5878 - acc: 0.7581 - RMSE: 0.2180 - val_loss: 1.7542 - val_acc: 0.5744 - val_RMSE: 0.3014
# Epoch 250/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5472 - acc: 0.7739 - RMSE: 0.2096 - val_loss: 1.6718 - val_acc: 0.5812 - val_RMSE: 0.2981
# Epoch 251/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5461 - acc: 0.7759 - RMSE: 0.2095 - val_loss: 1.8306 - val_acc: 0.5692 - val_RMSE: 0.3090
# Epoch 252/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5297 - acc: 0.7830 - RMSE: 0.2070 - val_loss: 1.7071 - val_acc: 0.5744 - val_RMSE: 0.2986
# Epoch 253/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.5629 - acc: 0.7640 - RMSE: 0.2136 - val_loss: 1.7398 - val_acc: 0.5590 - val_RMSE: 0.3019
# Epoch 254/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.5278 - acc: 0.7847 - RMSE: 0.2059 - val_loss: 1.7431 - val_acc: 0.5607 - val_RMSE: 0.2997
# Epoch 255/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5101 - acc: 0.7913 - RMSE: 0.2037 - val_loss: 1.8352 - val_acc: 0.5590 - val_RMSE: 0.3044
# Epoch 256/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5321 - acc: 0.7837 - RMSE: 0.2045 - val_loss: 1.7521 - val_acc: 0.5744 - val_RMSE: 0.2999
# Epoch 257/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5160 - acc: 0.7864 - RMSE: 0.2053 - val_loss: 1.6868 - val_acc: 0.5949 - val_RMSE: 0.2957
# Epoch 258/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.5085 - acc: 0.7963 - RMSE: 0.2031 - val_loss: 1.8158 - val_acc: 0.5726 - val_RMSE: 0.2999
# Epoch 259/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5116 - acc: 0.7921 - RMSE: 0.2025 - val_loss: 1.7302 - val_acc: 0.6017 - val_RMSE: 0.2963
# Epoch 260/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.4884 - acc: 0.8079 - RMSE: 0.1989 - val_loss: 1.7564 - val_acc: 0.5966 - val_RMSE: 0.2974
# Epoch 261/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5261 - acc: 0.7832 - RMSE: 0.2065 - val_loss: 1.6758 - val_acc: 0.6034 - val_RMSE: 0.2927
# Epoch 262/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.4956 - acc: 0.8018 - RMSE: 0.2009 - val_loss: 1.7776 - val_acc: 0.5675 - val_RMSE: 0.3006
# Epoch 263/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5464 - acc: 0.7797 - RMSE: 0.2085 - val_loss: 1.8212 - val_acc: 0.5573 - val_RMSE: 0.3062
# Epoch 264/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5171 - acc: 0.7938 - RMSE: 0.2040 - val_loss: 1.7437 - val_acc: 0.5863 - val_RMSE: 0.2990
# Epoch 265/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.5458 - acc: 0.7731 - RMSE: 0.2104 - val_loss: 1.7937 - val_acc: 0.5504 - val_RMSE: 0.3071
# Epoch 266/1000
# 5262/5262 [==============================] - 0s 18us/step - loss: 0.5207 - acc: 0.7860 - RMSE: 0.2066 - val_loss: 1.7820 - val_acc: 0.5795 - val_RMSE: 0.3026
# Epoch 267/1000
# 5262/5262 [==============================] - 0s 19us/step - loss: 0.5120 - acc: 0.7891 - RMSE: 0.2037 - val_loss: 1.8270 - val_acc: 0.5538 - val_RMSE: 0.3056
# Epoch 268/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5155 - acc: 0.7885 - RMSE: 0.2029 - val_loss: 1.7494 - val_acc: 0.5897 - val_RMSE: 0.2968
# Epoch 269/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4945 - acc: 0.7999 - RMSE: 0.2002 - val_loss: 1.8637 - val_acc: 0.5556 - val_RMSE: 0.3060
# Epoch 270/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.5296 - acc: 0.7853 - RMSE: 0.2059 - val_loss: 1.7645 - val_acc: 0.5761 - val_RMSE: 0.3000
# Epoch 271/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.4992 - acc: 0.7968 - RMSE: 0.2001 - val_loss: 1.8118 - val_acc: 0.5812 - val_RMSE: 0.2988
# Epoch 272/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4899 - acc: 0.8044 - RMSE: 0.1990 - val_loss: 1.8683 - val_acc: 0.5846 - val_RMSE: 0.2995
# Epoch 273/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4888 - acc: 0.7955 - RMSE: 0.1978 - val_loss: 1.8649 - val_acc: 0.5744 - val_RMSE: 0.3014
# Epoch 274/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.4822 - acc: 0.8033 - RMSE: 0.1984 - val_loss: 1.9088 - val_acc: 0.5573 - val_RMSE: 0.3049
# Epoch 275/1000
# 5262/5262 [==============================] - 0s 17us/step - loss: 0.5723 - acc: 0.7666 - RMSE: 0.2137 - val_loss: 1.8627 - val_acc: 0.5658 - val_RMSE: 0.3003
# Epoch 276/1000
# 5262/5262 [==============================] - 0s 16us/step - loss: 0.5171 - acc: 0.7872 - RMSE: 0.2046 - val_loss: 1.8408 - val_acc: 0.5915 - val_RMSE: 0.2985
# Epoch 277/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.4844 - acc: 0.8022 - RMSE: 0.1998 - val_loss: 1.8218 - val_acc: 0.5778 - val_RMSE: 0.3024
# Epoch 278/1000
# ...
# Epoch 701/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2299 - acc: 0.9166 - RMSE: 0.1314 - val_loss: 4.1531 - val_acc: 0.5709 - val_RMSE: 0.3249
# Epoch 702/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2312 - acc: 0.9122 - RMSE: 0.1327 - val_loss: 4.1285 - val_acc: 0.5863 - val_RMSE: 0.3206
# Epoch 703/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.2233 - acc: 0.9185 - RMSE: 0.1313 - val_loss: 4.2447 - val_acc: 0.5932 - val_RMSE: 0.3211
# Epoch 704/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2330 - acc: 0.9160 - RMSE: 0.1318 - val_loss: 4.2522 - val_acc: 0.5983 - val_RMSE: 0.3154
# Epoch 705/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.2863 - acc: 0.8947 - RMSE: 0.1473 - val_loss: 4.3227 - val_acc: 0.5538 - val_RMSE: 0.3278
# Epoch 706/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.2804 - acc: 0.8968 - RMSE: 0.1470 - val_loss: 4.1891 - val_acc: 0.5880 - val_RMSE: 0.3177
# Epoch 707/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2510 - acc: 0.9044 - RMSE: 0.1401 - val_loss: 4.1503 - val_acc: 0.5966 - val_RMSE: 0.3145
# Epoch 708/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3029 - acc: 0.8843 - RMSE: 0.1531 - val_loss: 4.2708 - val_acc: 0.5932 - val_RMSE: 0.3173
# Epoch 709/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.2620 - acc: 0.9038 - RMSE: 0.1432 - val_loss: 3.9806 - val_acc: 0.5915 - val_RMSE: 0.3137
# Epoch 710/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2933 - acc: 0.8922 - RMSE: 0.1490 - val_loss: 4.2570 - val_acc: 0.5744 - val_RMSE: 0.3225
# Epoch 711/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.3593 - acc: 0.8653 - RMSE: 0.1655 - val_loss: 4.1842 - val_acc: 0.5761 - val_RMSE: 0.3189
# Epoch 712/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3269 - acc: 0.8801 - RMSE: 0.1571 - val_loss: 4.3276 - val_acc: 0.5863 - val_RMSE: 0.3187
# Epoch 713/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3141 - acc: 0.8865 - RMSE: 0.1520 - val_loss: 4.1115 - val_acc: 0.5915 - val_RMSE: 0.3170
# Epoch 714/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3211 - acc: 0.8818 - RMSE: 0.1558 - val_loss: 4.1737 - val_acc: 0.5846 - val_RMSE: 0.3192
# Epoch 715/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3455 - acc: 0.8717 - RMSE: 0.1619 - val_loss: 4.1199 - val_acc: 0.5761 - val_RMSE: 0.3191
# Epoch 716/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2936 - acc: 0.8898 - RMSE: 0.1499 - val_loss: 3.9290 - val_acc: 0.5897 - val_RMSE: 0.3157
# Epoch 717/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3063 - acc: 0.8831 - RMSE: 0.1541 - val_loss: 4.2741 - val_acc: 0.5709 - val_RMSE: 0.3207
# Epoch 718/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2722 - acc: 0.8983 - RMSE: 0.1444 - val_loss: 4.1596 - val_acc: 0.5983 - val_RMSE: 0.3162
# Epoch 719/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2765 - acc: 0.8998 - RMSE: 0.1446 - val_loss: 4.1390 - val_acc: 0.5744 - val_RMSE: 0.3232
# Epoch 720/1000
# 5262/5262 [==============================] - 0s 15us/step - loss: 0.2399 - acc: 0.9130 - RMSE: 0.1353 - val_loss: 4.1288 - val_acc: 0.6000 - val_RMSE: 0.3145
# Epoch 721/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2287 - acc: 0.9171 - RMSE: 0.1315 - val_loss: 4.1552 - val_acc: 0.5983 - val_RMSE: 0.3137
# Epoch 722/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3010 - acc: 0.8930 - RMSE: 0.1492 - val_loss: 4.0708 - val_acc: 0.5846 - val_RMSE: 0.3136
# Epoch 723/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.2924 - acc: 0.8862 - RMSE: 0.1522 - val_loss: 4.3358 - val_acc: 0.5846 - val_RMSE: 0.3218
# Epoch 724/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2336 - acc: 0.9114 - RMSE: 0.1350 - val_loss: 4.2027 - val_acc: 0.5966 - val_RMSE: 0.3157
# Epoch 725/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2051 - acc: 0.9263 - RMSE: 0.1243 - val_loss: 4.2243 - val_acc: 0.5897 - val_RMSE: 0.3202
# Epoch 726/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2308 - acc: 0.9171 - RMSE: 0.1321 - val_loss: 4.1408 - val_acc: 0.5915 - val_RMSE: 0.3145
# Epoch 727/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2272 - acc: 0.9215 - RMSE: 0.1321 - val_loss: 4.2246 - val_acc: 0.5932 - val_RMSE: 0.3173
# Epoch 728/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2197 - acc: 0.9221 - RMSE: 0.1293 - val_loss: 4.3288 - val_acc: 0.5778 - val_RMSE: 0.3240
# Epoch 729/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2436 - acc: 0.9105 - RMSE: 0.1366 - val_loss: 4.3148 - val_acc: 0.5744 - val_RMSE: 0.3202
# Epoch 730/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2311 - acc: 0.9160 - RMSE: 0.1319 - val_loss: 4.0943 - val_acc: 0.5795 - val_RMSE: 0.3207
# Epoch 731/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2460 - acc: 0.9059 - RMSE: 0.1385 - val_loss: 4.2308 - val_acc: 0.5863 - val_RMSE: 0.3189
# Epoch 732/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2465 - acc: 0.9038 - RMSE: 0.1399 - val_loss: 4.3322 - val_acc: 0.5795 - val_RMSE: 0.3211
# Epoch 733/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2904 - acc: 0.8940 - RMSE: 0.1489 - val_loss: 4.4062 - val_acc: 0.5641 - val_RMSE: 0.3263
# Epoch 734/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3145 - acc: 0.8852 - RMSE: 0.1569 - val_loss: 4.4335 - val_acc: 0.5863 - val_RMSE: 0.3203
# Epoch 735/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4731 - acc: 0.8430 - RMSE: 0.1831 - val_loss: 4.4290 - val_acc: 0.5470 - val_RMSE: 0.3285
# Epoch 736/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4310 - acc: 0.8512 - RMSE: 0.1773 - val_loss: 4.3945 - val_acc: 0.5761 - val_RMSE: 0.3224
# Epoch 737/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3380 - acc: 0.8776 - RMSE: 0.1614 - val_loss: 4.0919 - val_acc: 0.5761 - val_RMSE: 0.3202
# Epoch 738/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4764 - acc: 0.8400 - RMSE: 0.1790 - val_loss: 4.1111 - val_acc: 0.5829 - val_RMSE: 0.3190
# Epoch 739/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3159 - acc: 0.8848 - RMSE: 0.1557 - val_loss: 4.2238 - val_acc: 0.5812 - val_RMSE: 0.3213
# Epoch 740/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4038 - acc: 0.8495 - RMSE: 0.1771 - val_loss: 3.9285 - val_acc: 0.5761 - val_RMSE: 0.3175
# Epoch 741/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3328 - acc: 0.8774 - RMSE: 0.1605 - val_loss: 3.8945 - val_acc: 0.6000 - val_RMSE: 0.3120
# Epoch 742/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2791 - acc: 0.8928 - RMSE: 0.1474 - val_loss: 3.8928 - val_acc: 0.6017 - val_RMSE: 0.3091
# Epoch 743/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2286 - acc: 0.9158 - RMSE: 0.1323 - val_loss: 4.0017 - val_acc: 0.5829 - val_RMSE: 0.3162
# Epoch 744/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2396 - acc: 0.9114 - RMSE: 0.1338 - val_loss: 4.1034 - val_acc: 0.5880 - val_RMSE: 0.3164
# Epoch 745/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2044 - acc: 0.9301 - RMSE: 0.1234 - val_loss: 4.1170 - val_acc: 0.5829 - val_RMSE: 0.3189
# Epoch 746/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2087 - acc: 0.9263 - RMSE: 0.1268 - val_loss: 4.1540 - val_acc: 0.5932 - val_RMSE: 0.3139
# Epoch 747/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2075 - acc: 0.9236 - RMSE: 0.1252 - val_loss: 4.2098 - val_acc: 0.5897 - val_RMSE: 0.3160
# Epoch 748/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2111 - acc: 0.9223 - RMSE: 0.1285 - val_loss: 4.2987 - val_acc: 0.5812 - val_RMSE: 0.3185
# Epoch 749/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2319 - acc: 0.9137 - RMSE: 0.1334 - val_loss: 4.3685 - val_acc: 0.5812 - val_RMSE: 0.3176
# Epoch 750/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2133 - acc: 0.9234 - RMSE: 0.1275 - val_loss: 4.1961 - val_acc: 0.5915 - val_RMSE: 0.3149
# Epoch 751/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2060 - acc: 0.9287 - RMSE: 0.1240 - val_loss: 4.3106 - val_acc: 0.6000 - val_RMSE: 0.3154
# Epoch 752/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2100 - acc: 0.9242 - RMSE: 0.1266 - val_loss: 4.4585 - val_acc: 0.5778 - val_RMSE: 0.3237
# Epoch 753/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2227 - acc: 0.9185 - RMSE: 0.1296 - val_loss: 4.5373 - val_acc: 0.5897 - val_RMSE: 0.3195
# Epoch 754/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2369 - acc: 0.9103 - RMSE: 0.1349 - val_loss: 4.3853 - val_acc: 0.5897 - val_RMSE: 0.3175
# Epoch 755/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2342 - acc: 0.9114 - RMSE: 0.1342 - val_loss: 4.2501 - val_acc: 0.5897 - val_RMSE: 0.3168
# Epoch 756/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2217 - acc: 0.9173 - RMSE: 0.1309 - val_loss: 4.5511 - val_acc: 0.5761 - val_RMSE: 0.3209
# Epoch 757/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2246 - acc: 0.9170 - RMSE: 0.1331 - val_loss: 4.3427 - val_acc: 0.5863 - val_RMSE: 0.3176
# Epoch 758/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2999 - acc: 0.8909 - RMSE: 0.1522 - val_loss: 4.6476 - val_acc: 0.5641 - val_RMSE: 0.3272
# Epoch 759/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4398 - acc: 0.8508 - RMSE: 0.1743 - val_loss: 4.1156 - val_acc: 0.5778 - val_RMSE: 0.3196
# Epoch 760/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3512 - acc: 0.8780 - RMSE: 0.1585 - val_loss: 4.6886 - val_acc: 0.5641 - val_RMSE: 0.3259
# Epoch 761/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3192 - acc: 0.8778 - RMSE: 0.1574 - val_loss: 4.2969 - val_acc: 0.5761 - val_RMSE: 0.3237
# Epoch 762/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2885 - acc: 0.8896 - RMSE: 0.1475 - val_loss: 4.3055 - val_acc: 0.5812 - val_RMSE: 0.3247
# Epoch 763/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2530 - acc: 0.9055 - RMSE: 0.1372 - val_loss: 4.2522 - val_acc: 0.5761 - val_RMSE: 0.3190
# Epoch 764/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2172 - acc: 0.9198 - RMSE: 0.1290 - val_loss: 4.2825 - val_acc: 0.5897 - val_RMSE: 0.3215
# Epoch 765/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2145 - acc: 0.9200 - RMSE: 0.1282 - val_loss: 4.2256 - val_acc: 0.5880 - val_RMSE: 0.3195
# Epoch 766/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2843 - acc: 0.9048 - RMSE: 0.1428 - val_loss: 4.3361 - val_acc: 0.5778 - val_RMSE: 0.3219
# Epoch 767/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2548 - acc: 0.9105 - RMSE: 0.1386 - val_loss: 4.1980 - val_acc: 0.5983 - val_RMSE: 0.3157
# Epoch 768/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2489 - acc: 0.9084 - RMSE: 0.1394 - val_loss: 4.3041 - val_acc: 0.5846 - val_RMSE: 0.3212
# Epoch 769/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3658 - acc: 0.8696 - RMSE: 0.1623 - val_loss: 4.0477 - val_acc: 0.5795 - val_RMSE: 0.3204
# Epoch 770/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2716 - acc: 0.8989 - RMSE: 0.1459 - val_loss: 4.2557 - val_acc: 0.5795 - val_RMSE: 0.3199
# Epoch 771/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2768 - acc: 0.8995 - RMSE: 0.1453 - val_loss: 4.3714 - val_acc: 0.5692 - val_RMSE: 0.3256
# Epoch 772/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2523 - acc: 0.8998 - RMSE: 0.1407 - val_loss: 4.2727 - val_acc: 0.5812 - val_RMSE: 0.3217
# Epoch 773/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2289 - acc: 0.9168 - RMSE: 0.1342 - val_loss: 4.2823 - val_acc: 0.6103 - val_RMSE: 0.3142
# Epoch 774/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2139 - acc: 0.9177 - RMSE: 0.1267 - val_loss: 4.3726 - val_acc: 0.5897 - val_RMSE: 0.3174
# Epoch 775/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2032 - acc: 0.9266 - RMSE: 0.1254 - val_loss: 4.4001 - val_acc: 0.5761 - val_RMSE: 0.3182
# Epoch 776/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2976 - acc: 0.8881 - RMSE: 0.1505 - val_loss: 4.6968 - val_acc: 0.5624 - val_RMSE: 0.3280
# Epoch 777/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3142 - acc: 0.8814 - RMSE: 0.1543 - val_loss: 4.3971 - val_acc: 0.5675 - val_RMSE: 0.3232
# Epoch 778/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3257 - acc: 0.8770 - RMSE: 0.1582 - val_loss: 4.4540 - val_acc: 0.5761 - val_RMSE: 0.3197
# Epoch 779/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2793 - acc: 0.8972 - RMSE: 0.1454 - val_loss: 4.1207 - val_acc: 0.5880 - val_RMSE: 0.3178
# Epoch 780/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2633 - acc: 0.9059 - RMSE: 0.1415 - val_loss: 4.5576 - val_acc: 0.5641 - val_RMSE: 0.3266
# Epoch 781/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2711 - acc: 0.8938 - RMSE: 0.1432 - val_loss: 4.4333 - val_acc: 0.5778 - val_RMSE: 0.3208
# Epoch 782/1000
# 5262/5262 [==============================] - 0s 14us/step - loss: 0.2467 - acc: 0.9124 - RMSE: 0.1368 - val_loss: 4.3063 - val_acc: 0.6000 - val_RMSE: 0.3154
# Epoch 783/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3297 - acc: 0.8848 - RMSE: 0.1567 - val_loss: 4.3182 - val_acc: 0.5829 - val_RMSE: 0.3211
# Epoch 784/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3717 - acc: 0.8677 - RMSE: 0.1679 - val_loss: 4.3407 - val_acc: 0.5795 - val_RMSE: 0.3174
# Epoch 785/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4569 - acc: 0.8404 - RMSE: 0.1806 - val_loss: 4.0057 - val_acc: 0.5436 - val_RMSE: 0.3253
# Epoch 786/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3524 - acc: 0.8677 - RMSE: 0.1656 - val_loss: 4.4369 - val_acc: 0.5726 - val_RMSE: 0.3216
# Epoch 787/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.4620 - acc: 0.8440 - RMSE: 0.1801 - val_loss: 4.2779 - val_acc: 0.5744 - val_RMSE: 0.3210
# Epoch 788/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.3268 - acc: 0.8780 - RMSE: 0.1569 - val_loss: 4.0430 - val_acc: 0.5761 - val_RMSE: 0.3179
# Epoch 789/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2706 - acc: 0.8983 - RMSE: 0.1437 - val_loss: 4.2733 - val_acc: 0.5744 - val_RMSE: 0.3245
# Epoch 790/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2246 - acc: 0.9171 - RMSE: 0.1297 - val_loss: 4.2591 - val_acc: 0.5846 - val_RMSE: 0.3201
# Epoch 791/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.2152 - acc: 0.9240 - RMSE: 0.1268 - val_loss: 4.2331 - val_acc: 0.5880 - val_RMSE: 0.3185
# Epoch 792/1000
# 5262/5262 [==============================] - 0s 13us/step - loss: 0.1931 - acc: 0.9310 - RMSE: 0.1190 - val_loss: 4.3561 - val_acc: 0.5983 - val_RMSE: 0.3161
#
# Deep learning trouxe uma acurácia de 0.62

# %% [markdown]
# ### Vamos plotar o histórico de treinamento

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation mse values
plt.plot(history.history['RMSE'])
plt.plot(history.history['val_RMSE'])
plt.title('Model mse')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
